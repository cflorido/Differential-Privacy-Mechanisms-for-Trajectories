# %% [markdown]
# ## Codigo principal para el mecanismo de Laplace

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import lambertw
import folium
def mecanismo_laplace_coordenadas(trayectoria, epsilon, semilla=None):
 """
 Aplica el Mecanismo de Laplace punto a punto sobre una trayectoria en R^2.
 
 Parámetros:
 trayectoria: array-like de forma (n, 2). Puntos (x1, x2) de la trayectoria original.
 epsilon: float > 0. Presupuesto de privacidad (parámetro de escala del Laplaciano).
 semilla: int o None. Semilla opcional para reproducibilidad.
 
 Retorna:
 np.ndarray de forma (n, 2) con la trayectoria perturbada.
 """
 # (Chequeo) Aseguramos que epsilon > 0, como asume el mecanismo.
 if epsilon <= 0:
 raise ValueError("epsilon debe ser > 0")
 
 # Generador de números aleatorios, opcionalmente con semilla para reproducibilidad.
 rng = np.random.default_rng(semilla)
 
 # Lista para acumular los puntos perturbados.
 puntos_perturbados = []
 
 # Recorremos cada punto x de la trayectoria original.
 for x1, x2 in np.asarray(trayectoria):
 # ------------------------------- Paso 1: Ángulo -------------------------------
 # Según (6), en coordenadas polares centradas en x, la densidad se factoriza:
 # D_e(r, θ) = (1 / 2π) * (ε^2 * r * e^{-ε r})
 # De ahí se desprende que θ ~ Uniforme(0, 2π). (independencia de r y θ)
 theta = rng.uniform(0.0, 2.0 * np.pi)
 
 # ------------------------------- Paso 2: Radio --------------------------------
 p = rng.uniform(0.0, 1.0)
 r = - (lambertw((p - 1.0) / np.e, k=-1).real + 1.0) / epsilon
 
 # ------------------------------- Paso 3: Cartesiano ---------------------------
 # Con (r, θ) obtenidos, transformamos a cartesianas alrededor de x:
 # z = x + (r cos θ, r sin θ) (ver pseudocódigo del paper)
 z1 = x1 + r * np.cos(theta)
 z2 = x2 + r * np.sin(theta)
 
 # Acumulamos el punto perturbado.
 puntos_perturbados.append((z1, z2))
 
 # Devolvemos como arreglo NumPy.
 return np.array(puntos_perturbados)

def cargar_trayectoria_real(ruta_archivo: str):
 """Carga trayectoria desde archivo PLT de GeoLife"""
 latlons = []
 with open(ruta_archivo, "r", encoding="utf-8", errors="ignore") as f:
 for i, linea in enumerate(f):
 if i < 6: continue # Saltar cabecera
 partes = linea.strip().split(",")
 try:
 latlons.append((float(partes[0]), float(partes[1])))
 except (ValueError, IndexError):
 continue
 return latlons
def latlon_to_local_xy(lat, lon, lat0, lon0):
 lat = np.radians(lat)
 lon = np.radians(lon)
 lat0 = np.radians(lat0)
 lon0 = np.radians(lon0)
 x = (lon - lon0) * np.cos(lat0) * R
 y = (lat - lat0) * R
 return x, y

def local_xy_to_latlon(x, y, lat0, lon0):
 lat0_rad = np.radians(lat0)
 lon0_rad = np.radians(lon0)
 lat = y / R + lat0_rad
 lon = x / (R * np.cos(lat0_rad)) + lon0_rad
 return np.degrees(lat), np.degrees(lon)

# %%
import numpy as np
from scipy.special import lambertw

def ejemplo_ilustrativo():
 x = np.array([0.0, 0.0])
 epsilon = 1.0
 
 # Fijamos los valores del ejemplo
 theta = np.pi / 4 # 45°
 p = 0.5
 
 # Radio con Lambert W
 r = - (lambertw((p - 1.0) / np.e, k=-1).real + 1.0) / epsilon
 
 # Coordenadas cartesianas
 z1 = x[0] + r * np.cos(theta)
 z2 = x[1] + r * np.sin(theta)
 
 return r, (z1, z2)

r, z = ejemplo_ilustrativo()
print("r =", r)
print("z =", z)
# Out:
# r = 1.6783469900166605
# z = (np.float64(1.1867705378248115), np.float64(1.1867705378248115))

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import lambertw

# ------------------ Configuración de estilo ------------------
plt.rcParams.update({
 "figure.figsize": (8, 8),
 "axes.titlesize": 16,
 "axes.labelsize": 14,
 "xtick.labelsize": 12,
 "ytick.labelsize": 12,
 "legend.fontsize": 12,
 "lines.linewidth": 2,
 "axes.grid": True,
 "grid.alpha": 0.3,
 "grid.linestyle": "--"
})

# ------------------ Ejemplo de trayectorias ------------------
N = 20
trayectoria_original = np.linspace((0.0, 0.0), (20.0, 20.0), N)
epsilon = 1

# Función del mecanismo de Laplace (tuya)
trayectoria_perturbada = mecanismo_laplace_coordenadas(trayectoria_original, epsilon=epsilon, semilla=41)

# ------------------ Gráfica mejorada azul rey + vino ------------------
fig, ax = plt.subplots()

color_original = "#1a237e" # Azul rey oscuro
color_perturbada = "#800020" # Vino intenso

# Trayectoria original
ax.plot(trayectoria_original[:, 0], trayectoria_original[:, 1],
 color=color_original, marker="o", markersize=5, label="Original", alpha=0.9)

# Trayectoria perturbada
ax.plot(trayectoria_perturbada[:, 0], trayectoria_perturbada[:, 1],
 color=color_perturbada, marker="s", markersize=5, label="Perturbada", alpha=0.9)

# Inicio y fin
ax.scatter(*trayectoria_original[0], color=color_original, s=100, edgecolor="k", label="Inicio Original", zorder=5)
ax.scatter(*trayectoria_original[-1], color=color_original, s=100, edgecolor="k", marker="X", label="Fin Original", zorder=5)
ax.scatter(*trayectoria_perturbada[0], color=color_perturbada, s=100, edgecolor="k", label="Inicio Perturbada", zorder=5)
ax.scatter(*trayectoria_perturbada[-1], color=color_perturbada, s=100, edgecolor="k", marker="X", label="Fin Perturbada", zorder=5)

# Título con ε y tamaño de la trayectoria
ax.set_title(f"Mecanismo de Laplace \nε = {epsilon}, N = {N} puntos", pad=20)

# Etiquetas
ax.set_xlabel("Coordenada X")
ax.set_ylabel("Coordenada Y")

# Ejes iguales y cuadrícula
ax.axis("equal")
ax.grid(True, linestyle="--", alpha=0.3)

# Leyenda
ax.legend(loc="best", frameon=True, shadow=True)

# Opcional: guardar en alta resolución
# plt.savefig("trayectorias_laplace_azul_vino.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Grafica dos trayectorias en mapa

# %%
import numpy as np
import folium

# ----------------- Funciones de conversión -----------------
R = 6371000.0 # radio de la Tierra en metros

def latlon_to_local_xy(lat, lon, lat0, lon0):
 """Convierte lat/lon a coordenadas locales XY en metros (proyección equirectangular)"""
 lat = np.radians(lat)
 lon = np.radians(lon)
 lat0 = np.radians(lat0)
 lon0 = np.radians(lon0)
 x = (lon - lon0) * np.cos(lat0) * R
 y = (lat - lat0) * R
 return x, y

def local_xy_to_latlon(x, y, lat0, lon0):
 """Convierte coordenadas locales XY a lat/lon"""
 lat0_rad = np.radians(lat0)
 lon0_rad = np.radians(lon0)
 lat = y / R + lat0_rad
 lon = x / (R * np.cos(lat0_rad)) + lon0_rad
 return np.degrees(lat), np.degrees(lon)

# ----------------- Función de Laplace -----------------
from scipy.special import lambertw

def mecanismo_laplace_coordenadas(trayectoria, epsilon, semilla=None):
 """Aplica el mecanismo de Laplace (R^2) sobre una trayectoria en coordenadas XY"""
 if epsilon <= 0:
 raise ValueError("epsilon debe ser > 0")
 rng = np.random.default_rng(semilla)
 puntos_perturbados = []
 for x1, x2 in np.asarray(trayectoria):
 theta = rng.uniform(0.0, 2.0 * np.pi)
 p = rng.uniform(0.0, 1.0)
 r = - (lambertw((p - 1.0)/np.e, k=-1).real + 1.0)/epsilon
 z1 = x1 + r * np.cos(theta)
 z2 = x2 + r * np.sin(theta)
 puntos_perturbados.append((z1, z2))
 return np.array(puntos_perturbados)

# ----------------- Cargar trayectoria -----------------
ruta_archivo = "../data/raw/geolife_trajectories_1_3/Data/000/Trajectory/20081023025304.plt"
latlons = []
with open(ruta_archivo, "r", encoding="utf-8", errors="ignore") as f:
 for i, linea in enumerate(f):
 if i < 6: continue # saltar cabecera
 partes = linea.strip().split(",")
 if len(partes) < 2: continue
 try:
 latlons.append((float(partes[0]), float(partes[1])))
 except ValueError:
 continue
latlons = np.array(latlons)
if len(latlons) == 0:
 raise RuntimeError("No se leyeron puntos de la trayectoria.")
print(f"Trayectoria cargada: {len(latlons)} puntos")

# ----------------- Conversión a XY -----------------
lat0, lon0 = latlons[0]
x, y = latlon_to_local_xy(latlons[:,0], latlons[:,1], lat0, lon0)
trayectoria_xy = np.column_stack([x, y])

# ----------------- Configurar epsilon según radio deseado -----------------
radio_medio_deseado_m = 243 # radio medio en metros
epsilon_m = 2 / radio_medio_deseado_m # R^2: r_medio = 2/epsilon
print(f"ε calculado automáticamente para r_medio={radio_medio_deseado_m} m: ε={epsilon_m:.5f}")

# ----------------- Aplicar Laplace -----------------
trayectoria_xy_pert = mecanismo_laplace_coordenadas(
 trayectoria_xy, epsilon=epsilon_m, semilla=42
)

# Verificación empírica del radio medio
radios_reales = np.linalg.norm(trayectoria_xy_pert - trayectoria_xy, axis=1)
radio_medio_real = np.mean(radios_reales)
print(f"Radio medio real (verificación): {radio_medio_real:.2f} m")
print(f"Diferencia relativa: {abs(radio_medio_real - radio_medio_deseado_m)/radio_medio_deseado_m*100:.1f}%")

# ----------------- Volver a lat/lon -----------------
lat_pert, lon_pert = local_xy_to_latlon(
 trayectoria_xy_pert[:,0], trayectoria_xy_pert[:,1], lat0, lon0
)

# ----------------- Mapa interactivo -----------------
m = folium.Map(location=[lat0, lon0], zoom_start=15)

# Trayectoria original
folium.PolyLine(
 locations=latlons.tolist(),
 color="blue", weight=3, opacity=0.9,
 tooltip="Trayectoria Original"
).add_to(m)

# Trayectoria perturbada
folium.PolyLine(
 locations=list(zip(lat_pert, lon_pert)),
 color="red", weight=3, opacity=0.8,
 tooltip=f"Trayectoria Perturbada (ε={epsilon_m:.3f}, r_medio≈{radio_medio_deseado_m}m)"
).add_to(m)

# Marcadores de inicio
folium.Marker([latlons[0,0], latlons[0,1]], popup="Inicio Original",
 icon=folium.Icon(color="blue")).add_to(m)
folium.Marker([lat_pert[0], lon_pert[0]], popup="Inicio Perturbado",
 icon=folium.Icon(color="red")).add_to(m)

# Guardar mapa
m.save("../artifacts/laplace/maps/trayectoria_laplace_mapa.html")
print("Mapa guardado: trayectoria_laplace_mapa.html")
# Out:
# Trayectoria cargada: 908 puntos
# Radio medio real (verificación): 244.93 m
# Diferencia relativa: 1124.6%
# Mapa guardado: trayectoria_laplace_mapa.html

# %% [markdown]
# ## Encontrar valores de epsilon comparables

# %%
import optuna
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt

# -----------------------
# Conversión lat/lon <-> XY metros
# -----------------------
R = 6371000.0 # radio Tierra en metros


# -----------------------
# Distancia media en metros
# -----------------------
def distancia_media_m(tray_orig, tray_pert):
 tray_orig = np.asarray(tray_orig)
 tray_pert = np.asarray(tray_pert)
 if tray_orig.shape != tray_pert.shape:
 raise ValueError("Las trayectorias deben tener la misma forma")
 dists = np.linalg.norm(tray_orig - tray_pert, axis=1)
 return float(np.mean(dists))

# -----------------------
# Usamos tu mecanismo Laplace (ya definido por ti)
# -----------------------
from scipy.special import lambertw

# -----------------------
# Cargar trayectoria GeoLife
# -----------------------
def cargar_trayectoria_real(ruta_archivo: str):
 latlons = []
 with open(ruta_archivo, "r", encoding="utf-8", errors="ignore") as f:
 for i, linea in enumerate(f):
 if i < 6: continue
 partes = linea.strip().split(",")
 try:
 latlons.append((float(partes[0]), float(partes[1])))
 except (ValueError, IndexError):
 continue
 return latlons

ruta_archivo = "../data/raw/geolife_trajectories_1_3/Data/000/Trajectory/20081023025304.plt"
latlons = np.array(cargar_trayectoria_real(ruta_archivo))
if len(latlons) == 0:
 raise RuntimeError("No se leyeron puntos de la trayectoria.")

lat0, lon0 = latlons[0]
x, y = latlon_to_local_xy(latlons[:,0], latlons[:,1], lat0, lon0)
trayectoria_xy = np.column_stack([x, y])

print(f"Trayectoria cargada: {len(trayectoria_xy)} puntos")

# -----------------------
# Optuna: buscar mejor ε
# -----------------------
target = 244.9982123264263 # distancia media deseada

def objective(trial):
 epsilon = trial.suggest_float("epsilon", 0.00005, 0.25)
 tray_pert = mecanismo_laplace_coordenadas(trayectoria_xy, epsilon=epsilon, semilla=41)
 dm = distancia_media_m(trayectoria_xy, tray_pert)
 return abs(dm - target)

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=200)

best_eps = study.best_params["epsilon"]
best_value = study.best_value

print(f"\n Mejor ε encontrado: {best_eps:.6f}")
print(f" Diferencia mínima con el target: {best_value:.6f}")
# Out:
# [I 2025-09-06 10:54:37,312] A new study created in memory with name: no-name-0de783a4-4c3b-47c8-b731-2db731a920cd
# [I 2025-09-06 10:54:37,326] Trial 0 finished with value: 236.13732334881252 and parameters: {'epsilon': 0.2266513768454379}. Best is trial 0 with value: 236.13732334881252.
# [I 2025-09-06 10:54:37,339] Trial 1 finished with value: 217.98303849071175 and parameters: {'epsilon': 0.07434091296483467}. Best is trial 1 with value: 217.98303849071175.
# [I 2025-09-06 10:54:37,351] Trial 2 finished with value: 210.22569924821389 and parameters: {'epsilon': 0.057756328463619284}. Best is trial 2 with value: 210.22569924821389.
# [I 2025-09-06 10:54:37,364] Trial 3 finished with value: 228.01634354089921 and parameters: {'epsilon': 0.11826334970638501}. Best is trial 2 with value: 210.22569924821389.
# [I 2025-09-06 10:54:37,377] Trial 4 finished with value: 236.1836470195302 and parameters: {'epsilon': 0.22784251031409444}. Best is trial 2 with value: 210.22569924821389.
# [I 2025-09-06 10:54:37,391] Trial 5 finished with value: 156.52941006349573 and parameters: {'epsilon': 0.005001729830931657}. Best is trial 5 with value: 156.52941006349573.
# [I 2025-09-06 10:54:37,404] Trial 6 finished with value: 55.06398251892216 and parameters: {'epsilon': 0.010573832262284442}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,417] Trial 7 finished with value: 211.64685600286361 and parameters: {'epsilon': 0.06021742166545263}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,429] Trial 8 finished with value: 225.5684073317833 and parameters: {'epsilon': 0.10336350197052678}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,442] Trial 9 finished with value: 236.7445562606839 and parameters: {'epsilon': 0.24332643265649417}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,458] Trial 10 finished with value: 233.4450557911488 and parameters: {'epsilon': 0.17383411024669307}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,475] Trial 11 finished with value: 22749.603001073738 and parameters: {'epsilon': 8.733931361594449e-05}. Best is trial 6 with value: 55.06398251892216.
# Trayectoria cargada: 908 puntos
# [I 2025-09-06 10:54:37,491] Trial 12 finished with value: 159.2855957627874 and parameters: {'epsilon': 0.004967630774882663}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,508] Trial 13 finished with value: 164.09233421686554 and parameters: {'epsilon': 0.024823075081529918}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,525] Trial 14 finished with value: 232.10824250170782 and parameters: {'epsilon': 0.15580584859085173}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,542] Trial 15 finished with value: 182.45525003431393 and parameters: {'epsilon': 0.03211124982329172}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,559] Trial 16 finished with value: 218.59014097586896 and parameters: {'epsilon': 0.07604995685564706}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,576] Trial 17 finished with value: 173.80008367841026 and parameters: {'epsilon': 0.02820766114204179}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,594] Trial 18 finished with value: 231.50931725492714 and parameters: {'epsilon': 0.1488878574713033}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,611] Trial 19 finished with value: 194.401567561734 and parameters: {'epsilon': 0.03969300130850183}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,628] Trial 20 finished with value: 224.1314500106638 and parameters: {'epsilon': 0.09624553423573831}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,644] Trial 21 finished with value: 55.93874067122036 and parameters: {'epsilon': 0.01062275626430078}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,662] Trial 22 finished with value: 289.1338668575606 and parameters: {'epsilon': 0.003759992640619784}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,680] Trial 23 finished with value: 198.1517947180609 and parameters: {'epsilon': 0.042870571313271655}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,697] Trial 24 finished with value: 141.55453450011584 and parameters: {'epsilon': 0.019414745579936478}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,714] Trial 25 finished with value: 164.67848220262687 and parameters: {'epsilon': 0.025004226032074882}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,731] Trial 26 finished with value: 215.55986729552646 and parameters: {'epsilon': 0.06822165732287924}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,747] Trial 27 finished with value: 222.5920886166226 and parameters: {'epsilon': 0.08963320531752642}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,764] Trial 28 finished with value: 204.09241394986083 and parameters: {'epsilon': 0.049096528280970754}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,780] Trial 29 finished with value: 142.73629346017324 and parameters: {'epsilon': 0.019639106219759134}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,797] Trial 30 finished with value: 229.91197296285716 and parameters: {'epsilon': 0.1331234801762814}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,814] Trial 31 finished with value: 142.93432502118696 and parameters: {'epsilon': 0.019677211400389596}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,841] Trial 32 finished with value: 118.2840208457569 and parameters: {'epsilon': 0.015849311457407762}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,859] Trial 33 finished with value: 205.39042841054734 and parameters: {'epsilon': 0.05070550503699307}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,876] Trial 34 finished with value: 234.87714035074725 and parameters: {'epsilon': 0.19843082745353036}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,892] Trial 35 finished with value: 86.96501365427613 and parameters: {'epsilon': 0.012708296128442903}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,909] Trial 36 finished with value: 217.26604950756638 and parameters: {'epsilon': 0.07241889858965195}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,927] Trial 37 finished with value: 102.07230989346297 and parameters: {'epsilon': 0.01405156555014725}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,945] Trial 38 finished with value: 191.68311737881766 and parameters: {'epsilon': 0.03766911957719049}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,962] Trial 39 finished with value: 211.34357187249446 and parameters: {'epsilon': 0.059674762819107816}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,978] Trial 40 finished with value: 79.39666723670891 and parameters: {'epsilon': 0.012127499690674302}. Best is trial 6 with value: 55.06398251892216.
# [I 2025-09-06 10:54:37,996] Trial 41 finished with value: 48.274659955872465 and parameters: {'epsilon': 0.010208908199602783}. Best is trial 41 with value: 48.274659955872465.
# [I 2025-09-06 10:54:38,012] Trial 42 finished with value: 4577.866920758154 and parameters: {'epsilon': 0.0004164190022801356}. Best is trial 41 with value: 48.274659955872465.
# [I 2025-09-06 10:54:38,029] Trial 43 finished with value: 187.14262867467528 and parameters: {'epsilon': 0.03471285846737719}. Best is trial 41 with value: 48.274659955872465.
# [I 2025-09-06 10:54:38,046] Trial 44 finished with value: 40.47364554795169 and parameters: {'epsilon': 0.009819518107211087}. Best is trial 44 with value: 40.47364554795169.
# [I 2025-09-06 10:54:38,063] Trial 45 finished with value: 205.79197815361647 and parameters: {'epsilon': 0.05122483016345258}. Best is trial 44 with value: 40.47364554795169.
# [I 2025-09-06 10:54:38,080] Trial 46 finished with value: 103.22096354632495 and parameters: {'epsilon': 0.014165408795353964}. Best is trial 44 with value: 40.47364554795169.
# [I 2025-09-06 10:54:38,096] Trial 47 finished with value: 6817.424459995715 and parameters: {'epsilon': 0.00028436880374229853}. Best is trial 44 with value: 40.47364554795169.
# [I 2025-09-06 10:54:38,113] Trial 48 finished with value: 227.01254925103586 and parameters: {'epsilon': 0.11166297725207097}. Best is trial 44 with value: 40.47364554795169.
# [I 2025-09-06 10:54:38,130] Trial 49 finished with value: 220.59036610138085 and parameters: {'epsilon': 0.082282257448424}. Best is trial 44 with value: 40.47364554795169.
# [I 2025-09-06 10:54:38,147] Trial 50 finished with value: 235.08440182972865 and parameters: {'epsilon': 0.20257928951937484}. Best is trial 44 with value: 40.47364554795169.
# [I 2025-09-06 10:54:38,165] Trial 51 finished with value: 74.22342591060672 and parameters: {'epsilon': 0.011760124131911631}. Best is trial 44 with value: 40.47364554795169.
# [I 2025-09-06 10:54:38,181] Trial 52 finished with value: 177.9056784614158 and parameters: {'epsilon': 0.02993377312133537}. Best is trial 44 with value: 40.47364554795169.
# [I 2025-09-06 10:54:38,199] Trial 53 finished with value: 33.479935960116194 and parameters: {'epsilon': 0.009494842343423213}. Best is trial 53 with value: 33.479935960116194.
# [I 2025-09-06 10:54:38,215] Trial 54 finished with value: 22.02935165737071 and parameters: {'epsilon': 0.00900723392864992}. Best is trial 54 with value: 22.02935165737071.
# [I 2025-09-06 10:54:38,232] Trial 55 finished with value: 169.81976021916353 and parameters: {'epsilon': 0.026714206405650576}. Best is trial 54 with value: 22.02935165737071.
# [I 2025-09-06 10:54:38,249] Trial 56 finished with value: 198.7171558704373 and parameters: {'epsilon': 0.04339427058586183}. Best is trial 54 with value: 22.02935165737071.
# [I 2025-09-06 10:54:38,267] Trial 57 finished with value: 179.85974123945982 and parameters: {'epsilon': 0.03083174433384238}. Best is trial 54 with value: 22.02935165737071.
# [I 2025-09-06 10:54:38,283] Trial 58 finished with value: 146.2913532709684 and parameters: {'epsilon': 0.005132599648509786}. Best is trial 54 with value: 22.02935165737071.
# [I 2025-09-06 10:54:38,300] Trial 59 finished with value: 213.9973219654994 and parameters: {'epsilon': 0.06478306472713473}. Best is trial 54 with value: 22.02935165737071.
# [I 2025-09-06 10:54:38,317] Trial 60 finished with value: 9.286422286029392 and parameters: {'epsilon': 0.008520289487880691}. Best is trial 60 with value: 9.286422286029392.
# [I 2025-09-06 10:54:38,334] Trial 61 finished with value: 2.740534464757303 and parameters: {'epsilon': 0.008106655550912015}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,350] Trial 62 finished with value: 172.17687398617153 and parameters: {'epsilon': 0.027578903829903273}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,367] Trial 63 finished with value: 5.959979151994304 and parameters: {'epsilon': 0.00800265843094995}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,384] Trial 64 finished with value: 33.09177915444218 and parameters: {'epsilon': 0.007221880500467059}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,401] Trial 65 finished with value: 146.568858435369 and parameters: {'epsilon': 0.020403798333102744}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,418] Trial 66 finished with value: 194.63312030858586 and parameters: {'epsilon': 0.03987548928014144}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,434] Trial 67 finished with value: 9.353809165549421 and parameters: {'epsilon': 0.007895878613703463}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,451] Trial 68 finished with value: 148.84855657162598 and parameters: {'epsilon': 0.020887570226692853}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,468] Trial 69 finished with value: 362.38010084616104 and parameters: {'epsilon': 0.00330655975574825}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,485] Trial 70 finished with value: 183.62039775734277 and parameters: {'epsilon': 0.03272082430680656}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,502] Trial 71 finished with value: 6.874057295225668 and parameters: {'epsilon': 0.007973615713502469}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,520] Trial 72 finished with value: 79.3442890612115 and parameters: {'epsilon': 0.006192012080619914}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,536] Trial 73 finished with value: 159.55442568096768 and parameters: {'epsilon': 0.023504724751773145}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,553] Trial 74 finished with value: 4458.650146960897 and parameters: {'epsilon': 0.0004269733903227045}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,570] Trial 75 finished with value: 140.72847297697888 and parameters: {'epsilon': 0.019260935141691016}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,587] Trial 76 finished with value: 199.30470628873968 and parameters: {'epsilon': 0.04395225626141104}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,603] Trial 77 finished with value: 16.162140755280916 and parameters: {'epsilon': 0.007690036650480416}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,621] Trial 78 finished with value: 236.7795509956967 and parameters: {'epsilon': 0.24436250698657747}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,637] Trial 79 finished with value: 230.09044531168476 and parameters: {'epsilon': 0.13471720378141094}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,654] Trial 80 finished with value: 139.63279143418805 and parameters: {'epsilon': 0.01906064313931553}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,673] Trial 81 finished with value: 10.819540295515651 and parameters: {'epsilon': 0.007850638457522265}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,691] Trial 82 finished with value: 17.312314690159212 and parameters: {'epsilon': 0.00765631753209718}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,708] Trial 83 finished with value: 109.65516361625896 and parameters: {'epsilon': 0.01483883144343462}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,725] Trial 84 finished with value: 166.4572329901661 and parameters: {'epsilon': 0.02557050731761811}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,742] Trial 85 finished with value: 188.73120175623774 and parameters: {'epsilon': 0.035692898316421154}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,759] Trial 86 finished with value: 24.489677316353664 and parameters: {'epsilon': 0.007452404223109553}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,776] Trial 87 finished with value: 208.22364854284177 and parameters: {'epsilon': 0.05461200569691639}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,793] Trial 88 finished with value: 117.92164238814556 and parameters: {'epsilon': 0.015804114698926425}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,810] Trial 89 finished with value: 1494.7380563479003 and parameters: {'epsilon': 0.0011543891582952845}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,828] Trial 90 finished with value: 162.40743194309005 and parameters: {'epsilon': 0.024316669215731754}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,845] Trial 91 finished with value: 22.756512412983056 and parameters: {'epsilon': 0.007500643317518793}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,861] Trial 92 finished with value: 2.8145025221197386 and parameters: {'epsilon': 0.008292600226801141}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,878] Trial 93 finished with value: 94.917301052818 and parameters: {'epsilon': 0.013381666394531677}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,895] Trial 94 finished with value: 233.63922360523787 and parameters: {'epsilon': 0.17680558860882598}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,913] Trial 95 finished with value: 7146.512938933244 and parameters: {'epsilon': 0.000271707996612908}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,931] Trial 96 finished with value: 137.75745853318722 and parameters: {'epsilon': 0.01872732721296247}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,947] Trial 97 finished with value: 179.4791927373047 and parameters: {'epsilon': 0.030652666957552973}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,964] Trial 98 finished with value: 39.04352377111576 and parameters: {'epsilon': 0.007070554892542475}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,981] Trial 99 finished with value: 107.25511129453793 and parameters: {'epsilon': 0.014580277863686205}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:38,998] Trial 100 finished with value: 42.78451355547662 and parameters: {'epsilon': 0.009931734096440228}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,016] Trial 101 finished with value: 127.07514384409916 and parameters: {'epsilon': 0.005397679391830177}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,033] Trial 102 finished with value: 28.577506026422157 and parameters: {'epsilon': 0.00927976218720388}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,051] Trial 103 finished with value: 151.6041101149832 and parameters: {'epsilon': 0.021503849164949337}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,068] Trial 104 finished with value: 126.04196454074173 and parameters: {'epsilon': 0.01688295254965516}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,086] Trial 105 finished with value: 166.46939638344654 and parameters: {'epsilon': 0.025574467954654973}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,103] Trial 106 finished with value: 166.66189333096963 and parameters: {'epsilon': 0.004878618693554359}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,120] Trial 107 finished with value: 236.2481473682327 and parameters: {'epsilon': 0.2295220317159039}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,136] Trial 108 finished with value: 190.9079986787943 and parameters: {'epsilon': 0.03712931695803454}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,155] Trial 109 finished with value: 75.79834436144182 and parameters: {'epsilon': 0.011869587789905097}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,173] Trial 110 finished with value: 174.66516437985396 and parameters: {'epsilon': 0.028554609042058584}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,190] Trial 111 finished with value: 288.63719913076744 and parameters: {'epsilon': 0.003763492159125267}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,207] Trial 112 finished with value: 31.262455242681654 and parameters: {'epsilon': 0.007269701852683536}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,225] Trial 113 finished with value: 113.94233459560598 and parameters: {'epsilon': 0.015324247348720295}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,242] Trial 114 finished with value: 23.16192755528894 and parameters: {'epsilon': 0.009053219985732624}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,260] Trial 115 finished with value: 155.83736663401265 and parameters: {'epsilon': 0.02252482770048036}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,277] Trial 116 finished with value: 21.305191352314523 and parameters: {'epsilon': 0.008978074855018212}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,294] Trial 117 finished with value: 1674.6390902883209 and parameters: {'epsilon': 0.0010462042408298563}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,310] Trial 118 finished with value: 136.95981683605896 and parameters: {'epsilon': 0.018589064357493135}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,329] Trial 119 finished with value: 87.15040085576308 and parameters: {'epsilon': 0.012723221615422858}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,346] Trial 120 finished with value: 4483.0993988358705 and parameters: {'epsilon': 0.0004247654875206841}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,364] Trial 121 finished with value: 10.31954110370998 and parameters: {'epsilon': 0.007866012683682349}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,382] Trial 122 finished with value: 117.68361914720191 and parameters: {'epsilon': 0.005537450493978679}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,399] Trial 123 finished with value: 93.79740351827098 and parameters: {'epsilon': 0.013282552538451836}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,416] Trial 124 finished with value: 150.8450994596128 and parameters: {'epsilon': 0.021330496950129195}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,433] Trial 125 finished with value: 21.159492095853437 and parameters: {'epsilon': 0.008972230920468012}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,451] Trial 126 finished with value: 182.0585604903912 and parameters: {'epsilon': 0.031908862350917784}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,469] Trial 127 finished with value: 131.63091906526796 and parameters: {'epsilon': 0.017715274212503625}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,488] Trial 128 finished with value: 166.737085082721 and parameters: {'epsilon': 0.02566194428297439}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,506] Trial 129 finished with value: 45.08949673186805 and parameters: {'epsilon': 0.010046248763480144}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,523] Trial 130 finished with value: 224.106152018726 and parameters: {'epsilon': 0.09612899145760699}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,541] Trial 131 finished with value: 94.39603713854598 and parameters: {'epsilon': 0.00591740340331844}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,574] Trial 132 finished with value: 68.12565079149337 and parameters: {'epsilon': 0.01135468763171659}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,601] Trial 133 finished with value: 210.38686325664224 and parameters: {'epsilon': 0.004410185564995282}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,622] Trial 134 finished with value: 126.75754504662041 and parameters: {'epsilon': 0.016985126463285226}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,640] Trial 135 finished with value: 8965.71457599724 and parameters: {'epsilon': 0.0002180431344463024}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,657] Trial 136 finished with value: 47.49932439902764 and parameters: {'epsilon': 0.01016883035609297}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,675] Trial 137 finished with value: 156.60604688533294 and parameters: {'epsilon': 0.022720709203454634}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,691] Trial 138 finished with value: 122.90426506856167 and parameters: {'epsilon': 0.016449076567318276}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,709] Trial 139 finished with value: 40.89628280189032 and parameters: {'epsilon': 0.007024733672991305}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,726] Trial 140 finished with value: 94.38253665058201 and parameters: {'epsilon': 0.013334154481855376}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,743] Trial 141 finished with value: 5.940816674452037 and parameters: {'epsilon': 0.00800326953860854}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,766] Trial 142 finished with value: 139.21507645539674 and parameters: {'epsilon': 0.005227129684187405}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,788] Trial 143 finished with value: 59.57270701076936 and parameters: {'epsilon': 0.010830940886108805}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,805] Trial 144 finished with value: 7802.599731145873 and parameters: {'epsilon': 0.0002495567871255008}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,827] Trial 145 finished with value: 126.03510677016789 and parameters: {'epsilon': 0.016881979311652896}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,843] Trial 146 finished with value: 170.0670706761416 and parameters: {'epsilon': 0.026802376723738384}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,861] Trial 147 finished with value: 6.138675659099306 and parameters: {'epsilon': 0.007996964137608035}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,878] Trial 148 finished with value: 155.62959310496217 and parameters: {'epsilon': 0.02247245962113268}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,896] Trial 149 finished with value: 232.87075099741102 and parameters: {'epsilon': 0.16560206892152643}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,914] Trial 150 finished with value: 228.68283502559672 and parameters: {'epsilon': 0.12309446786428989}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,932] Trial 151 finished with value: 17.218935985363714 and parameters: {'epsilon': 0.007659044039571055}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,950] Trial 152 finished with value: 182.02548960597272 and parameters: {'epsilon': 0.004703094178994}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,967] Trial 153 finished with value: 87.66926738911886 and parameters: {'epsilon': 0.012765182450381374}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:39,984] Trial 154 finished with value: 38718.211102985115 and parameters: {'epsilon': 5.1544334312869644e-05}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:40,002] Trial 155 finished with value: 20.964883029725485 and parameters: {'epsilon': 0.008964437091371253}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:40,019] Trial 156 finished with value: 127.08106898512354 and parameters: {'epsilon': 0.017031727787347753}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:40,038] Trial 157 finished with value: 25.83577756862178 and parameters: {'epsilon': 0.009163672091296734}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:40,055] Trial 158 finished with value: 149.27275847991132 and parameters: {'epsilon': 0.02098013230703372}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:40,074] Trial 159 finished with value: 169.39663676880213 and parameters: {'epsilon': 0.004846422901335865}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:40,090] Trial 160 finished with value: 98.51330092690114 and parameters: {'epsilon': 0.013710167604724675}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:40,108] Trial 161 finished with value: 27.250111374810842 and parameters: {'epsilon': 0.009223192661951134}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:40,125] Trial 162 finished with value: 143.96993768648304 and parameters: {'epsilon': 0.005163231711347267}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:40,143] Trial 163 finished with value: 91.45546341914567 and parameters: {'epsilon': 0.01307995786934556}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:40,161] Trial 164 finished with value: 9.361830392415982 and parameters: {'epsilon': 0.008523016141935015}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:40,179] Trial 165 finished with value: 142.01762172981805 and parameters: {'epsilon': 0.01950205058269379}. Best is trial 61 with value: 2.740534464757303.
# [I 2025-09-06 10:54:40,196] Trial 166 finished with value: 0.7305356268313119 and parameters: {'epsilon': 0.008221852002631605}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,214] Trial 167 finished with value: 231.75916310926658 and parameters: {'epsilon': 0.004212483729308614}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,231] Trial 168 finished with value: 119.96945763509976 and parameters: {'epsilon': 0.016062966409678685}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,249] Trial 169 finished with value: 4778.819089794984 and parameters: {'epsilon': 0.00039976228554383826}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,267] Trial 170 finished with value: 39.88142216916145 and parameters: {'epsilon': 0.009791166707079066}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,285] Trial 171 finished with value: 9.840814220054597 and parameters: {'epsilon': 0.008540376373539736}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,302] Trial 172 finished with value: 101.47136619714584 and parameters: {'epsilon': 0.013992731959300127}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,319] Trial 173 finished with value: 98.87063182767929 and parameters: {'epsilon': 0.005840403168222754}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,337] Trial 174 finished with value: 31.322007577114732 and parameters: {'epsilon': 0.009398953379984185}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,355] Trial 175 finished with value: 141.5032977095786 and parameters: {'epsilon': 0.01940513400379}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,379] Trial 176 finished with value: 222.98582302033452 and parameters: {'epsilon': 0.004291455552244696}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,397] Trial 177 finished with value: 164.27042156667423 and parameters: {'epsilon': 0.024877835351986562}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,414] Trial 178 finished with value: 234.95370964357514 and parameters: {'epsilon': 0.19994346661677276}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,432] Trial 179 finished with value: 101.91517302638306 and parameters: {'epsilon': 0.014036133819042573}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,449] Trial 180 finished with value: 27.87685091644255 and parameters: {'epsilon': 0.009249816203291303}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,467] Trial 181 finished with value: 40.06463647049105 and parameters: {'epsilon': 0.009799920186151233}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,485] Trial 182 finished with value: 3697.0444543051676 and parameters: {'epsilon': 0.0005094649796286502}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,503] Trial 183 finished with value: 126.37195910208821 and parameters: {'epsilon': 0.016929917554191896}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,520] Trial 184 finished with value: 62.07771148025995 and parameters: {'epsilon': 0.006540182838023608}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,537] Trial 185 finished with value: 79.52222095729778 and parameters: {'epsilon': 0.012136701344007855}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,555] Trial 186 finished with value: 138.28252958876783 and parameters: {'epsilon': 0.0052398476292218835}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,572] Trial 187 finished with value: 143.22338828137333 and parameters: {'epsilon': 0.019733099081180427}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,589] Trial 188 finished with value: 108.43833589950353 and parameters: {'epsilon': 0.014706608847331906}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,607] Trial 189 finished with value: 3469.566496252315 and parameters: {'epsilon': 0.0005406643427727925}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,625] Trial 190 finished with value: 220.59689891638098 and parameters: {'epsilon': 0.0823042863759932}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,642] Trial 191 finished with value: 226.75544455419396 and parameters: {'epsilon': 0.11008925355656039}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,661] Trial 192 finished with value: 8.106158368466453 and parameters: {'epsilon': 0.007934800498849148}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,678] Trial 193 finished with value: 32.799707540874294 and parameters: {'epsilon': 0.009464405457900645}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,695] Trial 194 finished with value: 118.80705768339965 and parameters: {'epsilon': 0.005520350727180209}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,714] Trial 195 finished with value: 77.84092962906308 and parameters: {'epsilon': 0.012014628704432838}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,732] Trial 196 finished with value: 7.044366918093829 and parameters: {'epsilon': 0.007968227800519144}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,750] Trial 197 finished with value: 261.54782553183924 and parameters: {'epsilon': 0.0039647584558003745}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,768] Trial 198 finished with value: 24029.040838057652 and parameters: {'epsilon': 8.27358266451729e-05}. Best is trial 166 with value: 0.7305356268313119.
# [I 2025-09-06 10:54:40,785] Trial 199 finished with value: 123.09543733495234 and parameters: {'epsilon': 0.01647487259409148}. Best is trial 166 with value: 0.7305356268313119.
#  Mejor ε encontrado: 0.008222
#  Diferencia mínima con el target: 0.730536

# %% [markdown]
# ## Poblar base de datos laplace

# %%
import time
import math
import numpy as np
import pandas as pd
from typing import List, Tuple
from scipy.spatial.distance import directed_hausdorff
from scipy.special import lambertw

# ---- TIPOS ----
Point = Tuple[float, float]
Trajectory = List[Point]

# ---- RADIO TIERRA ----
R = 6371000.0


# ---- MÉTRICAS ----
def haversine_distance(p1: Point, p2: Point) -> float:
 lat1, lon1 = math.radians(p1[0]), math.radians(p1[1])
 lat2, lon2 = math.radians(p2[0]), math.radians(p2[1])
 dlat = lat2 - lat1
 dlon = lon2 - lon1
 a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
 return R * 2 * math.atan2(math.sqrt(a), math.sqrt(1-a))

def trajectory_length(traj: Trajectory) -> float:
 return sum(haversine_distance(traj[i], traj[i+1]) for i in range(len(traj)-1))

def mean_displacement(original: Trajectory, perturbed: Trajectory) -> float:
 return np.mean([haversine_distance(o, p) for o, p in zip(original, perturbed)])

def max_displacement(original: Trajectory, perturbed: Trajectory) -> float:
 return np.max([haversine_distance(o, p) for o, p in zip(original, perturbed)])

def std_displacement(original: Trajectory, perturbed: Trajectory) -> float:
 return np.std([haversine_distance(o, p) for o, p in zip(original, perturbed)])

def trajectory_length_error(original: Trajectory, perturbed: Trajectory) -> float:
 return abs(trajectory_length(original) - trajectory_length(perturbed))

def mean_direction_error(original: Trajectory, perturbed: Trajectory) -> float:
 def bearing(p1: Point, p2: Point) -> float:
 lat1, lon1 = math.radians(p1[0]), math.radians(p1[1])
 lat2, lon2 = math.radians(p2[0]), math.radians(p2[1])
 dlon = lon2 - lon1
 y = math.sin(dlon) * math.cos(lat2)
 x = math.cos(lat1)*math.sin(lat2) - math.sin(lat1)*math.cos(lat2)*math.cos(dlon)
 return math.atan2(y, x)
 
 errors = []
 for i in range(len(original)-1):
 theta_orig = bearing(original[i], original[i+1])
 theta_pert = bearing(perturbed[i], perturbed[i+1])
 errors.append(abs(theta_orig - theta_pert))
 return np.mean(errors)

def hausdorff_distance(original: Trajectory, perturbed: Trajectory) -> float:
 a = np.array(original)
 b = np.array(perturbed)
 return max(directed_hausdorff(a, b)[0], directed_hausdorff(b, a)[0])

# ---- EVALUADOR ----
def evaluate_method(method_name: str, original: Trajectory, perturbed: Trajectory, runtime: float, epsilon: float) -> dict:
 return {
 "Método": method_name,
 "Tamaño Trayectoria": len(original),
 "Epsilon": epsilon,
 "Distancia Media (m)": mean_displacement(original, perturbed),
 "Distancia Máx (m)": max_displacement(original, perturbed),
 "Desv. Estándar (m)": std_displacement(original, perturbed),
 "Error Longitud (m)": trajectory_length_error(original, perturbed),
 "Error Dirección (rad)": mean_direction_error(original, perturbed),
 "Hausdorff (m)": hausdorff_distance(original, perturbed),
 "Tiempo (s)": runtime
 }


# ---- CARGAR TRAJECTORIA ----
def cargar_trayectoria_real(ruta: str) -> Trajectory:
 latlons = []
 with open(ruta, "r", encoding="utf-8", errors="ignore") as f:
 for i, linea in enumerate(f):
 if i < 6:
 continue
 partes = linea.strip().split(",")
 if len(partes) < 2:
 continue
 try:
 lat = float(partes[0])
 lon = float(partes[1])
 latlons.append((lat, lon))
 except ValueError:
 continue
 return latlons

# ---- EXPERIMENTO ----
ruta_archivo = "../data/raw/geolife_trajectories_1_3/Data/000/Trajectory/20081023025304.plt"
original_trajectory = cargar_trayectoria_real(ruta_archivo)

lat0, lon0 = original_trajectory[0]
xs, ys = latlon_to_local_xy([p[0] for p in original_trajectory],
 [p[1] for p in original_trajectory],
 lat0, lon0)
trayectoria_xy = np.column_stack([xs, ys])

epsilons = np.linspace(0.00822, 0.048, 10) # 10 valores de epsilon
results = []
N_RUNS = 10

for epsilon in epsilons:
 for run in range(N_RUNS):
 start_time = time.time()
 perturbed_xy = mecanismo_laplace_coordenadas(trayectoria_xy, epsilon=epsilon, semilla=run)
 lat_pert, lon_pert = local_xy_to_latlon(perturbed_xy[:,0], perturbed_xy[:,1], lat0, lon0)
 perturbed_trajectory = list(zip(lat_pert, lon_pert))
 runtime = time.time() - start_time
 result = evaluate_method("Laplace", original_trajectory, perturbed_trajectory, runtime, epsilon)
 result["Run"] = run
 results.append(result)

# ---- GUARDAR RESULTADOS ----
df_results = pd.DataFrame(results)
print(df_results.head())
df_results.to_csv("../artifacts/laplace/analysis_outputs/laplace_summary_metrics.csv", index=False)
# Out:
#  Método Tamaño Trayectoria Epsilon Distancia Media (m) \
# 0 Laplace 908 0.00822 241.976482
# 1 Laplace 908 0.00822 249.796930
# 2 Laplace 908 0.00822 242.446324
# 3 Laplace 908 0.00822 240.456237
# 4 Laplace 908 0.00822 238.956430
#
#  Distancia Máx (m) Desv. Estándar (m) Error Longitud (m) \
# 0 1034.086946 170.779692 307424.358661
# 1 1332.705558 179.414849 323204.054556
# 2 1230.855906 170.499832 307827.851981
# 3 930.987303 166.341524 309166.772009
# 4 916.809586 163.740189 302334.092380
#
#  Error Dirección (rad) Hausdorff (m) Tiempo (s) Run
# 0 1.922978 0.008344 0.032013 0
# 1 1.902442 0.010847 0.044998 1
# 2 1.804573 0.008917 0.022526 2
# 3 1.901313 0.009223 0.017999 3
# 4 1.904105 0.007320 0.019018 4

# %% [markdown]
# ## Graficas base de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Leer datos
df = pd.read_csv("../artifacts/laplace/analysis_outputs/laplace_summary_metrics.csv")

# Agrupar por epsilon y promediar todas las métricas
df_avg = df.groupby("Epsilon", as_index=False).mean(numeric_only=True)

metricas = [
 "Distancia Media (m)",
 "Distancia Máx (m)",
 "Desv. Estándar (m)",
 "Error Longitud (m)",
 "Error Dirección (rad)",
 "Hausdorff (m)",
 "Tiempo (s)"
]

# Descripciones para cada métrica
descripciones = {
 "Distancia Media (m)": "Promedio de la distancia entre trayectorias originales y aproximadas.",
 "Distancia Máx (m)": "Mayor distancia registrada entre dos trayectorias.",
 "Desv. Estándar (m)": "Variabilidad de la distancia entre las trayectorias.",
 "Error Longitud (m)": "Diferencia en longitud total entre las trayectorias.",
 "Error Dirección (rad)": "Diferencia en orientación promedio entre las trayectorias.",
 "Hausdorff (m)": "Distancia Hausdorff que mide la similitud entre trayectorias.",
 "Tiempo (s)": "Tiempo requerido para el procesamiento."
}

sns.set_theme(style="whitegrid")
plt.rcParams.update({'font.size': 13})

palette = sns.color_palette("mako", len(metricas))

# Índices y etiquetas para epsilon
annot_indices = [1, 3, 5, 7, 9]
epsilons_labels = [r'$\epsilon$ = 1', r'$\epsilon$ = 2', r'$\epsilon$ = 3', r'$\epsilon$ = 4', r'$\epsilon$ = 5']

for i, metrica in enumerate(metricas):
 print(f"\n Gráfica de {metrica}")
 print(f"Descripción: {descripciones[metrica]}\n")
 
 plt.figure(figsize=(10, 6))
 ax = sns.lineplot(data=df_avg, x="Epsilon", y=metrica, marker="o", linewidth=2.8, color=palette[i])
 
 ax.set_title(metrica, fontsize=15, fontweight="bold", color="#333333")
 ax.set_xlabel("Epsilon", fontsize=13)
 ax.set_ylabel(metrica, fontsize=13)
 ax.set_facecolor("#f9f9f9")
 
 # Mostrar números completos en el eje Y
 ax.ticklabel_format(style='plain', axis='y')
 
 # Anotaciones de epsilon (solo si hay suficientes puntos)
 for idx, label in zip(annot_indices, epsilons_labels):
 if idx < len(df_avg):
 x = df_avg["Epsilon"].iloc[idx]
 y = df_avg[metrica].iloc[idx]
 offset_y = 15
 if y == df_avg[metrica].max():
 offset_y += 20
 
 ax.annotate(label,
 xy=(x, y),
 xytext=(0, offset_y),
 textcoords="offset points",
 ha="center",
 fontsize=11,
 color="black",
 bbox=dict(boxstyle="round,pad=0.3", edgecolor="gray", facecolor="white", alpha=0.8))
 
 # Anotaciones de máximo y mínimo
 max_val = df_avg[metrica].max()
 min_val = df_avg[metrica].min()
 max_idx = df_avg[metrica].idxmax()
 min_idx = df_avg[metrica].idxmin()
 
 ax.annotate(f"Max: {max_val:.2f}", xy=(df_avg["Epsilon"][max_idx], max_val),
 xytext=(10, -30), textcoords="offset points",
 fontsize=10, color="darkred", fontweight="bold")
 
 ax.annotate(f"Min: {min_val:.2f}", xy=(df_avg["Epsilon"][min_idx], min_val),
 xytext=(10, 10), textcoords="offset points",
 fontsize=10, color="darkblue", fontweight="bold")
 
 plt.tight_layout()
 plt.show()
# Out:
#  Gráfica de Distancia Media (m)
# Descripción: Promedio de la distancia entre trayectorias originales y aproximadas.
#  Gráfica de Distancia Máx (m)
# Descripción: Mayor distancia registrada entre dos trayectorias.
#  Gráfica de Desv. Estándar (m)
# Descripción: Variabilidad de la distancia entre las trayectorias.
#  Gráfica de Error Longitud (m)
# Descripción: Diferencia en longitud total entre las trayectorias.
#  Gráfica de Error Dirección (rad)
# Descripción: Diferencia en orientación promedio entre las trayectorias.
#  Gráfica de Hausdorff (m)
# Descripción: Distancia Hausdorff que mide la similitud entre trayectorias.
#  Gráfica de Tiempo (s)
# Descripción: Tiempo requerido para el procesamiento.

# %% [markdown]
# ## Mapas de calor

# %%
epsilons = [0.01264, 0.02148, 0.03032, 0.03916, 0.04358]
pasos_m = [1000, 1500, 2000, 2500, 3000]
# Out:
# [0.00822 0.01264 0.01706 0.02148 0.0259 0.03032 0.03474 0.03916 0.04358
#  0.048 ]

# %%
import numpy as np
import pandas as pd
from scipy.sparse import dok_matrix
import os
from glob import glob
epsilons = [0.01264, 0.02148, 0.03032, 0.03916, 0.04358]
pasos_m = [1000, 1500, 2000, 2500, 3000]
# ----------------- Constantes -----------------
R = 6371000.0 # Radio de la Tierra en metros
carpeta_salida = "../artifacts/laplace/analysis_outputs"
os.makedirs(carpeta_salida, exist_ok=True)

# ----------------- Funciones auxiliares -----------------
def cargar_trayectoria(ruta_archivo):
 latlons = []
 with open(ruta_archivo, "r", encoding="utf-8", errors="ignore") as f:
 for i, linea in enumerate(f):
 if i < 6: continue # Saltar cabecera
 partes = linea.strip().split(",")
 try:
 latlons.append((float(partes[0]), float(partes[1])))
 except (ValueError, IndexError):
 continue
 return np.array(latlons)

def latlon_a_celda(lat, lon, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = paso_m / (111000 * np.cos(np.radians((lat_min + lat.max())/2)))
 i = ((lat - lat_min) // paso_lat).astype(int)
 j = ((lon - lon_min) // paso_lon).astype(int)
 return i, j

def obtener_celdas_unificadas(trayectorias, trayectorias_pert, paso_m):
 todas_lats = np.concatenate([tray[:,0] for tray in trayectorias + trayectorias_pert])
 todas_lons = np.concatenate([tray[:,1] for tray in trayectorias + trayectorias_pert])
 lat_min, lon_min = todas_lats.min(), todas_lons.min()
 celdas = {}
 idx = 0
 for tray in trayectorias + trayectorias_pert:
 i, j = latlon_a_celda(tray[:,0], tray[:,1], lat_min, lon_min, paso_m)
 for c in zip(i, j):
 if c not in celdas:
 celdas[c] = idx
 idx += 1
 return celdas, lat_min, lon_min

def construir_matriz_od_sparse(trayectorias, celdas, lat_min, lon_min, paso_m):
 n = len(celdas)
 OD = dok_matrix((n, n), dtype=int)
 for tray in trayectorias:
 i, j = latlon_a_celda(tray[:,0], tray[:,1], lat_min, lon_min, paso_m)
 origen = celdas[(i[0], j[0])]
 destino = celdas[(i[-1], j[-1])]
 OD[origen, destino] += 1
 return OD

# ----------------- Cargar trayectorias -----------------
ruta_carpeta = "../data/raw/geolife_trajectories_1_3/Data/002/Trajectory"
archivos_plt = glob(os.path.join(ruta_carpeta, "*.plt"))
trayectorias = [cargar_trayectoria(f) for f in archivos_plt if len(cargar_trayectoria(f)) > 0]

# ----------------- Funciones de conversión y perturbación -----------------
# (Debes definirlas si aún no las tienes)
def latlon_to_local_xy(lat, lon, lat0, lon0):
 x = (lon - lon0) * np.cos(np.radians(lat0)) * 111000
 y = (lat - lat0) * 111000
 return x, y

def local_xy_to_latlon(x, y, lat0, lon0):
 lat = y / 111000 + lat0
 lon = x / (111000 * np.cos(np.radians(lat0))) + lon0
 return lat, lon

def mecanismo_laplace_coordenadas(tray, epsilon):
 sensibilidad = 1.0
 ruido_x = np.random.laplace(0, sensibilidad / epsilon, size=len(tray))
 ruido_y = np.random.laplace(0, sensibilidad / epsilon, size=len(tray))
 tray_pert = np.copy(tray)
 tray_pert[:,0] += ruido_x
 tray_pert[:,1] += ruido_y
 return tray_pert

# ----------------- Bucle principal -----------------
for paso_m in pasos_m:
 for epsilon in epsilons:
 print(f"\nProcesando paso = {paso_m} m, ε = {epsilon:.5f}")

 # Convertir trayectorias a coordenadas locales
 trayectorias_xy = []
 for tray in trayectorias:
 lat0, lon0 = tray[0]
 x, y = latlon_to_local_xy(tray[:,0], tray[:,1], lat0, lon0)
 trayectorias_xy.append(np.column_stack([x, y]))

 # Aplicar Laplace
 trayectorias_pert_xy = [mecanismo_laplace_coordenadas(tray, epsilon=epsilon) for tray in trayectorias_xy]

 # Convertir de nuevo a lat/lon
 trayectorias_pert_latlon = []
 for tray_orig, tray_pert in zip(trayectorias, trayectorias_pert_xy):
 lat0, lon0 = tray_orig[0]
 lat, lon = local_xy_to_latlon(tray_pert[:,0], tray_pert[:,1], lat0, lon0)
 trayectorias_pert_latlon.append(np.column_stack([lat, lon]))

 # Crear celdas y matrices OD
 celdas_unificadas, lat_min, lon_min = obtener_celdas_unificadas(trayectorias, trayectorias_pert_latlon, paso_m)
 OD_original = construir_matriz_od_sparse(trayectorias, celdas_unificadas, lat_min, lon_min, paso_m)
 OD_perturbada = construir_matriz_od_sparse(trayectorias_pert_latlon, celdas_unificadas, lat_min, lon_min, paso_m)
 
 # Guardar resultados
 archivo_od_original = os.path.join(carpeta_salida, f"OD_original_eps{epsilon:.5f}_paso{paso_m}.csv")
 archivo_od_perturbada = os.path.join(carpeta_salida, f"OD_perturbada_eps{epsilon:.5f}_paso{paso_m}.csv")
 archivo_celdas = os.path.join(carpeta_salida, f"celdas_eps{epsilon:.5f}_paso{paso_m}.csv")
 archivo_minimos = os.path.join(carpeta_salida, f"minimos_eps{epsilon:.5f}_paso{paso_m}.csv")

 # Guardar matrices OD
 pd.DataFrame(OD_original.toarray()).to_csv(archivo_od_original, index=False)
 pd.DataFrame(OD_perturbada.toarray()).to_csv(archivo_od_perturbada, index=False)

 # Guardar celdas_unificadas
 df_celdas = pd.DataFrame(
 [(clave[0], clave[1], valor) for clave, valor in celdas_unificadas.items()],
 columns=["i", "j", "indice"]
 )
 df_celdas.to_csv(archivo_celdas, index=False)

 # Guardar lat_min y lon_min
 df_minimos = pd.DataFrame({
 "lat_min": [lat_min],
 "lon_min": [lon_min]
 })
 df_minimos.to_csv(archivo_minimos, index=False)
# Out:
# Procesando paso = 1000 m, ε = 0.00822
#
# Procesando paso = 1000 m, ε = 0.01264
#
# Procesando paso = 1000 m, ε = 0.01706
#
# Procesando paso = 1000 m, ε = 0.02148
#
# Procesando paso = 1000 m, ε = 0.02590
#
# Procesando paso = 1000 m, ε = 0.03032
#
# Procesando paso = 1000 m, ε = 0.03474
#
# Procesando paso = 1000 m, ε = 0.03916
#
# Procesando paso = 1000 m, ε = 0.04358
#
# Procesando paso = 1000 m, ε = 0.04800
#
# Procesando paso = 1500 m, ε = 0.00822
#
# Procesando paso = 1500 m, ε = 0.01264
#
# Procesando paso = 1500 m, ε = 0.01706
#
# Procesando paso = 1500 m, ε = 0.02148
#
# Procesando paso = 1500 m, ε = 0.02590
#
# Procesando paso = 1500 m, ε = 0.03032
#
# Procesando paso = 1500 m, ε = 0.03474
#
# Procesando paso = 1500 m, ε = 0.03916
#
# Procesando paso = 1500 m, ε = 0.04358
#
# Procesando paso = 1500 m, ε = 0.04800
#
# Procesando paso = 2000 m, ε = 0.00822
#
# Procesando paso = 2000 m, ε = 0.01264
#
# Procesando paso = 2000 m, ε = 0.01706
#
# Procesando paso = 2000 m, ε = 0.02148
#
# Procesando paso = 2000 m, ε = 0.02590
#
# Procesando paso = 2000 m, ε = 0.03032
#
# Procesando paso = 2000 m, ε = 0.03474
#
# Procesando paso = 2000 m, ε = 0.03916
#
# Procesando paso = 2000 m, ε = 0.04358
#
# Procesando paso = 2000 m, ε = 0.04800
#
# Procesando paso = 2500 m, ε = 0.00822
#
# Procesando paso = 2500 m, ε = 0.01264
#
# Procesando paso = 2500 m, ε = 0.01706
#
# Procesando paso = 2500 m, ε = 0.02148
#
# Procesando paso = 2500 m, ε = 0.02590
#
# Procesando paso = 2500 m, ε = 0.03032
#
# Procesando paso = 2500 m, ε = 0.03474
#
# Procesando paso = 2500 m, ε = 0.03916
#
# Procesando paso = 2500 m, ε = 0.04358
#
# Procesando paso = 2500 m, ε = 0.04800
#
# Procesando paso = 3000 m, ε = 0.00822
#
# Procesando paso = 3000 m, ε = 0.01264
#
# Procesando paso = 3000 m, ε = 0.01706
#
# Procesando paso = 3000 m, ε = 0.02148
#
# Procesando paso = 3000 m, ε = 0.02590
#
# Procesando paso = 3000 m, ε = 0.03032
#
# Procesando paso = 3000 m, ε = 0.03474
#
# Procesando paso = 3000 m, ε = 0.03916
#
# Procesando paso = 3000 m, ε = 0.04358
#
# Procesando paso = 3000 m, ε = 0.04800

# %% [markdown]
# # Grafica de trayectorias

# %%
import folium

# ---------- MAPA 1: Trayectorias originales ----------
lat_c, lon_c = trayectorias_originales_latlon[0][0]
mapa_original = folium.Map(location=[lat_c, lon_c], zoom_start=12)

for idx, tray in enumerate(trayectorias_originales_latlon):
 coords = [(lat, lon) for lat, lon in tray]

 # Dibujar la trayectoria
 folium.PolyLine(coords, color="blue", weight=2, opacity=0.7).add_to(mapa_original)

 # Marcar inicio (verde)
 folium.CircleMarker(
 location=coords[0],
 radius=4,
 color="green",
 fill=True,
 fill_opacity=1,
 popup=f"Inicio Trayectoria {idx}"
 ).add_to(mapa_original)

 # Marcar fin (rojo)
 folium.CircleMarker(
 location=coords[-1],
 radius=4,
 color="red",
 fill=True,
 fill_opacity=1,
 popup=f"Fin Trayectoria {idx}"
 ).add_to(mapa_original)

mapa_original.save("../artifacts/laplace/maps/mapa_trayectorias_originales.html")


# ---------- MAPA 2: Trayectorias perturbadas ----------
lat_c2, lon_c2 = trayectorias_perturbadas_latlon[0][0]
mapa_perturbado = folium.Map(location=[lat_c2, lon_c2], zoom_start=12)

for idx, tray in enumerate(trayectorias_perturbadas_latlon):
 coords = [(lat, lon) for lat, lon in tray]

 # Dibujar la trayectoria
 folium.PolyLine(coords, color="red", weight=2, opacity=0.7).add_to(mapa_perturbado)

 # Marcar inicio (verde)
 folium.CircleMarker(
 location=coords[0],
 radius=4,
 color="green",
 fill=True,
 fill_opacity=1,
 popup=f"Inicio Trayectoria {idx}"
 ).add_to(mapa_perturbado)

 # Marcar fin (black)
 folium.CircleMarker(
 location=coords[-1],
 radius=4,
 color="black",
 fill=True,
 fill_opacity=1,
 popup=f"Fin Trayectoria {idx}"
 ).add_to(mapa_perturbado)

mapa_perturbado.save("../artifacts/laplace/maps/mapa_trayectorias_perturbadas.html")

print(" Mapas generados con INICIO (verde) y FIN (rojo/negro).")
# Out:
#  Mapas generados con INICIO (verde) y FIN (rojo/negro).

# %% [markdown]
# # Archivo a usar

# %%
import os
import pandas as pd
import numpy as np
from glob import glob

epsilons = np.linspace(0.00822, 0.048, 10)
pasos_m = [1000, 1500, 2000, 2500, 3000]

# %%
epsilon=0.00822
paso_m=1500

# %%
def cargar_trayectoria(ruta_archivo):
 latlons = []
 with open(ruta_archivo, "r", encoding="utf-8", errors="ignore") as f:
 for i, linea in enumerate(f):
 if i < 6: continue # Saltar cabecera
 partes = linea.strip().split(",")
 try:
 latlons.append((float(partes[0]), float(partes[1])))
 except (ValueError, IndexError):
 continue 
 return np.array(latlons)

# %%
ruta_carpeta = "../data/raw/geolife_trajectories_1_3/Data/002/Trajectory"
archivos_plt = glob(os.path.join(ruta_carpeta, "*.plt"))
trayectorias = [cargar_trayectoria(f) for f in archivos_plt if len(cargar_trayectoria(f)) > 0]



carpeta_salida = "../artifacts/laplace/analysis_outputs"

# Rutas de los archivos
archivo_od_original = os.path.join(carpeta_salida, f"OD_original_eps{epsilon:.5f}_paso{paso_m}.csv")
archivo_od_perturbada = os.path.join(carpeta_salida, f"OD_perturbada_eps{epsilon:.5f}_paso{paso_m}.csv")
archivo_celdas = os.path.join(carpeta_salida, f"celdas_eps{epsilon:.5f}_paso{paso_m}.csv")
archivo_minimos = os.path.join(carpeta_salida, f"minimos_eps{epsilon:.5f}_paso{paso_m}.csv")

# Leer las matrices OD
OD_original = pd.read_csv(archivo_od_original).values
OD_perturbada = pd.read_csv(archivo_od_perturbada).values

# Leer las celdas y reconstruir el diccionario
df_celdas = pd.read_csv(archivo_celdas)
celdas_unificadas = {(row["i"], row["j"]): row["indice"] for _, row in df_celdas.iterrows()}

# Leer lat_min y lon_min desde su archivo
df_minimos = pd.read_csv(archivo_minimos)
lat_min = df_minimos["lat_min"].iloc[0]
lon_min = df_minimos["lon_min"].iloc[0]

# %% [markdown]
# # Matrices Origen - Destino

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Graficar heatmap para OD original
plt.figure(figsize=(8,6))
sns.heatmap(OD_original, cmap="YlGnBu", cbar=True)
plt.title(f"Matriz OD Original (ε={epsilon}, paso={paso_m} m)")
plt.xlabel("Destino")
plt.ylabel("Origen")
plt.show()

# Graficar heatmap para OD perturbada
plt.figure(figsize=(8,6))
sns.heatmap(OD_perturbada, cmap="YlGnBu", cbar=True)
plt.title(f"Matriz OD Perturbada (ε={epsilon}, paso={paso_m} m)")
plt.xlabel("Destino")
plt.ylabel("Origen")
plt.show()

# %% [markdown]
# # Mapa de calor por zonas mas transitadas

# %%
import folium
from folium import plugins
from branca.colormap import LinearColormap
import numpy as np
import matplotlib.pyplot as plt



def celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = (paso_m / (111000 * np.cos(np.radians(lat_min))))
 lat_centro = lat_min + (i + 0.5) * paso_lat
 lon_centro = lon_min + (j + 0.5) * paso_lon
 return lat_centro, lon_centro

# Cantidad de viajes por celda
viajes_por_celda = np.array([OD_original[i,i] for i in range(len(celdas_unificadas))])

# Crear mapa
lat_centro = np.mean([lat_min, np.max(np.concatenate([tray[:,0] for tray in trayectorias]))])
lon_centro = np.mean([lon_min, np.max(np.concatenate([tray[:,1] for tray in trayectorias]))])
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=12, tiles="CartoDB positron")

# Crear colormap usando matplotlib 'plasma'
colormap = LinearColormap(
 colors=[plt.cm.plasma(i/255)[:3] for i in range(0,256,5)], # colores del 0 al 255
 vmin=0,
 vmax=viajes_por_celda.max()
)
colormap.caption = "Número de viajes por celda"
colormap.add_to(m)

# Dibujar celdas
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))
 
 # Color según número de viajes
 intensidad = viajes_por_celda[idx]
 color_hex = colormap(intensidad)
 
 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color=color_hex,
 fill=True,
 fill_color=color_hex,
 fill_opacity=0.7,
 tooltip=f"Zona: {idx}\nViajes: {viajes_por_celda[idx]}"
 ).add_to(m)

# Guardar mapa
m.save("../artifacts/laplace/maps/celdas_beijing_original.html")

# %%
import folium
from folium import plugins
from branca.colormap import LinearColormap
import numpy as np
import matplotlib.pyplot as plt



def celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = (paso_m / (111000 * np.cos(np.radians(lat_min))))
 lat_centro = lat_min + (i + 0.5) * paso_lat
 lon_centro = lon_min + (j + 0.5) * paso_lon
 return lat_centro, lon_centro

# Cantidad de viajes por celda
viajes_por_celda = np.array([OD_perturbada[i,i] for i in range(len(celdas_unificadas))])

# Crear mapa
lat_centro = np.mean([lat_min, np.max(np.concatenate([tray[:,0] for tray in trayectorias]))])
lon_centro = np.mean([lon_min, np.max(np.concatenate([tray[:,1] for tray in trayectorias]))])
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=12, tiles="CartoDB positron")

# Crear colormap usando matplotlib 'plasma'
colormap = LinearColormap(
 colors=[plt.cm.plasma(i/255)[:3] for i in range(0,256,5)], # colores del 0 al 255
 vmin=0,
 vmax=viajes_por_celda.max()
)
colormap.caption = "Número de viajes por celda"
colormap.add_to(m)

# Dibujar celdas
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))
 
 # Color según número de viajes
 intensidad = viajes_por_celda[idx]
 color_hex = colormap(intensidad)
 
 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color=color_hex,
 fill=True,
 fill_color=color_hex,
 fill_opacity=0.7,
 tooltip=f"Zona: {idx}\nViajes: {viajes_por_celda[idx]}"
 ).add_to(m)

# Guardar mapa
m.save("../artifacts/laplace/maps/celdas_beijing_perturbado.html")

# %% [markdown]
# # Mapa de calor por destino

# %%
import folium
from folium import plugins
from branca.colormap import LinearColormap
import numpy as np
import matplotlib.pyplot as plt

def celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = (paso_m / (111000 * np.cos(np.radians(lat_min))))
 lat_centro = lat_min + (i + 0.5) * paso_lat
 lon_centro = lon_min + (j + 0.5) * paso_lon
 return lat_centro, lon_centro

# Ahora calculamos los viajes por celda destino (sumando por columnas)
viajes_por_celda = np.array([OD_original[:, i].sum() for i in range(len(celdas_unificadas))])

# Crear mapa centrado en el área
lat_centro = np.mean([lat_min, np.max(np.concatenate([tray[:,0] for tray in trayectorias]))])
lon_centro = np.mean([lon_min, np.max(np.concatenate([tray[:,1] for tray in trayectorias]))])
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=12, tiles="CartoDB positron")

# Crear colormap usando matplotlib 'plasma'
colormap = LinearColormap(
 colors=[plt.cm.plasma(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda.max()
)
colormap.caption = "Número de viajes con destino en celda"
colormap.add_to(m)

# Dibujar celdas
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))
 
 intensidad = viajes_por_celda[idx]
 color_hex = colormap(intensidad)
 
 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color=color_hex,
 fill=True,
 fill_color=color_hex,
 fill_opacity=0.7,
 tooltip=f"Zona destino: {idx}\nViajes recibidos: {viajes_por_celda[idx]}"
 ).add_to(m)

# Guardar mapa
m.save("../artifacts/laplace/maps/celdas_destino_original.html")
# Ahora calculamos los viajes por celda destino (sumando por columnas)
viajes_por_celda = np.array([OD_original[:, i].sum() for i in range(len(celdas_unificadas))])

# Imprimir en terminal
print("=== VIAJES POR CELDA DESTINO ===")
for idx, num_viajes in enumerate(viajes_por_celda):
 print(f"Celda destino {idx}: {num_viajes} viajes")

print("\nTOTAL de viajes considerados:", viajes_por_celda.sum())
# Out:
# === VIAJES POR CELDA DESTINO ===
# Celda destino 0: 2 viajes
# Celda destino 1: 1 viajes
# Celda destino 2: 3 viajes
# Celda destino 3: 8 viajes
# Celda destino 4: 7 viajes
# Celda destino 5: 17 viajes
# Celda destino 6: 90 viajes
# Celda destino 7: 9 viajes
# Celda destino 8: 3 viajes
# Celda destino 9: 3 viajes
# Celda destino 10: 8 viajes
# Celda destino 11: 1 viajes
# Celda destino 12: 1 viajes
# Celda destino 13: 25 viajes
# Celda destino 14: 0 viajes
# Celda destino 15: 1 viajes
# Celda destino 16: 2 viajes
# Celda destino 17: 2 viajes
# Celda destino 18: 2 viajes
# Celda destino 19: 0 viajes
# Celda destino 20: 1 viajes
# Celda destino 21: 2 viajes
# Celda destino 22: 1 viajes
# Celda destino 23: 3 viajes
# Celda destino 24: 28 viajes
# Celda destino 25: 2 viajes
# Celda destino 26: 4 viajes
# Celda destino 27: 8 viajes
# Celda destino 28: 14 viajes
# Celda destino 29: 2 viajes
# Celda destino 30: 5 viajes
# Celda destino 31: 0 viajes
# Celda destino 32: 2 viajes
# Celda destino 33: 14 viajes
# Celda destino 34: 1 viajes
# Celda destino 35: 1 viajes
# Celda destino 36: 2 viajes
# Celda destino 37: 2 viajes
# Celda destino 38: 2 viajes
# Celda destino 39: 0 viajes
# Celda destino 40: 0 viajes
# Celda destino 41: 1 viajes
# Celda destino 42: 5 viajes
# Celda destino 43: 7 viajes
# Celda destino 44: 2 viajes
# Celda destino 45: 1 viajes
# Celda destino 46: 3 viajes
# Celda destino 47: 2 viajes
# Celda destino 48: 1 viajes
# Celda destino 49: 56 viajes
# Celda destino 50: 5 viajes
# Celda destino 51: 1 viajes
# Celda destino 52: 1 viajes
# Celda destino 53: 0 viajes
# Celda destino 54: 0 viajes
# Celda destino 55: 1 viajes
# Celda destino 56: 2 viajes
# Celda destino 57: 2 viajes
# Celda destino 58: 5 viajes
# Celda destino 59: 3 viajes
# Celda destino 60: 1 viajes
# Celda destino 61: 0 viajes
# Celda destino 62: 1 viajes
# Celda destino 63: 1 viajes
# Celda destino 64: 0 viajes
# Celda destino 65: 2 viajes
# Celda destino 66: 0 viajes
# Celda destino 67: 0 viajes
# Celda destino 68: 2 viajes
# Celda destino 69: 3 viajes
# Celda destino 70: 41 viajes
# Celda destino 71: 3 viajes
# Celda destino 72: 1 viajes
# Celda destino 73: 2 viajes
# Celda destino 74: 0 viajes
# Celda destino 75: 1 viajes
# Celda destino 76: 1 viajes
# Celda destino 77: 0 viajes
# Celda destino 78: 0 viajes
# Celda destino 79: 1 viajes
# Celda destino 80: 0 viajes
# Celda destino 81: 0 viajes
# Celda destino 82: 0 viajes
# Celda destino 83: 0 viajes
# Celda destino 84: 0 viajes
# Celda destino 85: 2 viajes
# Celda destino 86: 1 viajes
# Celda destino 87: 2 viajes
# Celda destino 88: 4 viajes
# Celda destino 89: 0 viajes
# Celda destino 90: 0 viajes
# Celda destino 91: 0 viajes
# Celda destino 92: 0 viajes
# Celda destino 93: 0 viajes
# Celda destino 94: 0 viajes
# Celda destino 95: 0 viajes
# Celda destino 96: 0 viajes
# Celda destino 97: 7 viajes
# Celda destino 98: 3 viajes
# Celda destino 99: 1 viajes
# Celda destino 100: 0 viajes
# Celda destino 101: 0 viajes
# Celda destino 102: 0 viajes
# Celda destino 103: 1 viajes
# Celda destino 104: 1 viajes
# Celda destino 105: 0 viajes
# Celda destino 106: 0 viajes
# Celda destino 107: 0 viajes
# Celda destino 108: 6 viajes
# Celda destino 109: 0 viajes
# Celda destino 110: 0 viajes
# Celda destino 111: 0 viajes
# Celda destino 112: 2 viajes
# Celda destino 113: 8 viajes
# Celda destino 114: 0 viajes
# Celda destino 115: 1 viajes
# Celda destino 116: 1 viajes
# Celda destino 117: 4 viajes
# Celda destino 118: 1 viajes
# Celda destino 119: 0 viajes
# Celda destino 120: 0 viajes
# Celda destino 121: 2 viajes
# Celda destino 122: 0 viajes
# Celda destino 123: 0 viajes
# Celda destino 124: 0 viajes
# Celda destino 125: 0 viajes
# Celda destino 126: 0 viajes
# Celda destino 127: 0 viajes
# Celda destino 128: 0 viajes
# Celda destino 129: 0 viajes
# Celda destino 130: 0 viajes
# Celda destino 131: 0 viajes
# Celda destino 132: 0 viajes
# Celda destino 133: 0 viajes
# Celda destino 134: 0 viajes
# Celda destino 135: 0 viajes
# Celda destino 136: 0 viajes
# Celda destino 137: 0 viajes
# Celda destino 138: 0 viajes
# Celda destino 139: 0 viajes
# Celda destino 140: 0 viajes
# Celda destino 141: 0 viajes
# Celda destino 142: 0 viajes
# Celda destino 143: 0 viajes
# Celda destino 144: 0 viajes
#
# TOTAL de viajes considerados: 484

# %%
import folium
from folium import plugins
from branca.colormap import LinearColormap
import numpy as np
import matplotlib.pyplot as plt

def celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = (paso_m / (111000 * np.cos(np.radians(lat_min))))
 lat_centro = lat_min + (i + 0.5) * paso_lat
 lon_centro = lon_min + (j + 0.5) * paso_lon
 return lat_centro, lon_centro

# Cantidad de viajes por celda destino (sumando columnas)
viajes_por_celda = np.array([OD_perturbada[:, i].sum() for i in range(len(celdas_unificadas))])

# Imprimir número de viajes por celda y total
print("=== VIAJES POR CELDA DESTINO (PERTURBADA) ===")
for idx, num_viajes in enumerate(viajes_por_celda):
 print(f"Celda destino {idx}: {num_viajes} viajes")
print("TOTAL de viajes considerados:", viajes_por_celda.sum())

# Crear mapa centrado
lat_centro = np.mean([lat_min, np.max(np.concatenate([tray[:,0] for tray in trayectorias]))])
lon_centro = np.mean([lon_min, np.max(np.concatenate([tray[:,1] for tray in trayectorias]))])
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=12, tiles="CartoDB positron")

# Crear colormap usando matplotlib 'plasma'
colormap = LinearColormap(
 colors=[plt.cm.plasma(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda.max()
)
colormap.caption = "Número de viajes destino por celda (perturbada)"
colormap.add_to(m)

# Dibujar celdas destino
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))
 
 intensidad = viajes_por_celda[idx]
 color_hex = colormap(intensidad)
 
 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color=color_hex,
 fill=True,
 fill_color=color_hex,
 fill_opacity=0.9,
 tooltip=f"Celda destino: {idx}\nViajes recibidos: {intensidad}"
 ).add_to(m)

# Guardar mapa
m.save("../artifacts/laplace/maps/celdas_destino_perturbado.html")
# Ahora calculamos los viajes por celda destino (sumando por columnas)
viajes_por_celda = np.array([OD_original[:, i].sum() for i in range(len(celdas_unificadas))])

# Imprimir en terminal
print("=== VIAJES POR CELDA DESTINO ===")
for idx, num_viajes in enumerate(viajes_por_celda):
 print(f"Celda destino {idx}: {num_viajes} viajes")

print("\nTOTAL de viajes considerados:", viajes_por_celda.sum())
# Out:
# === VIAJES POR CELDA DESTINO (PERTURBADA) ===
# Celda destino 0: 2 viajes
# Celda destino 1: 3 viajes
# Celda destino 2: 4 viajes
# Celda destino 3: 8 viajes
# Celda destino 4: 8 viajes
# Celda destino 5: 23 viajes
# Celda destino 6: 80 viajes
# Celda destino 7: 7 viajes
# Celda destino 8: 6 viajes
# Celda destino 9: 3 viajes
# Celda destino 10: 8 viajes
# Celda destino 11: 1 viajes
# Celda destino 12: 1 viajes
# Celda destino 13: 22 viajes
# Celda destino 14: 1 viajes
# Celda destino 15: 2 viajes
# Celda destino 16: 2 viajes
# Celda destino 17: 1 viajes
# Celda destino 18: 3 viajes
# Celda destino 19: 1 viajes
# Celda destino 20: 1 viajes
# Celda destino 21: 2 viajes
# Celda destino 22: 1 viajes
# Celda destino 23: 5 viajes
# Celda destino 24: 22 viajes
# Celda destino 25: 1 viajes
# Celda destino 26: 4 viajes
# Celda destino 27: 8 viajes
# Celda destino 28: 9 viajes
# Celda destino 29: 2 viajes
# Celda destino 30: 4 viajes
# Celda destino 31: 0 viajes
# Celda destino 32: 3 viajes
# Celda destino 33: 19 viajes
# Celda destino 34: 1 viajes
# Celda destino 35: 0 viajes
# Celda destino 36: 2 viajes
# Celda destino 37: 2 viajes
# Celda destino 38: 1 viajes
# Celda destino 39: 2 viajes
# Celda destino 40: 0 viajes
# Celda destino 41: 1 viajes
# Celda destino 42: 5 viajes
# Celda destino 43: 5 viajes
# Celda destino 44: 2 viajes
# Celda destino 45: 2 viajes
# Celda destino 46: 2 viajes
# Celda destino 47: 1 viajes
# Celda destino 48: 12 viajes
# Celda destino 49: 24 viajes
# Celda destino 50: 5 viajes
# Celda destino 51: 1 viajes
# Celda destino 52: 1 viajes
# Celda destino 53: 1 viajes
# Celda destino 54: 0 viajes
# Celda destino 55: 1 viajes
# Celda destino 56: 3 viajes
# Celda destino 57: 0 viajes
# Celda destino 58: 5 viajes
# Celda destino 59: 17 viajes
# Celda destino 60: 1 viajes
# Celda destino 61: 0 viajes
# Celda destino 62: 2 viajes
# Celda destino 63: 1 viajes
# Celda destino 64: 1 viajes
# Celda destino 65: 11 viajes
# Celda destino 66: 0 viajes
# Celda destino 67: 0 viajes
# Celda destino 68: 1 viajes
# Celda destino 69: 3 viajes
# Celda destino 70: 27 viajes
# Celda destino 71: 7 viajes
# Celda destino 72: 3 viajes
# Celda destino 73: 2 viajes
# Celda destino 74: 0 viajes
# Celda destino 75: 1 viajes
# Celda destino 76: 0 viajes
# Celda destino 77: 0 viajes
# Celda destino 78: 0 viajes
# Celda destino 79: 1 viajes
# Celda destino 80: 0 viajes
# Celda destino 81: 0 viajes
# Celda destino 82: 0 viajes
# Celda destino 83: 0 viajes
# Celda destino 84: 1 viajes
# Celda destino 85: 1 viajes
# Celda destino 86: 1 viajes
# Celda destino 87: 1 viajes
# Celda destino 88: 5 viajes
# Celda destino 89: 0 viajes
# Celda destino 90: 1 viajes
# Celda destino 91: 0 viajes
# Celda destino 92: 1 viajes
# Celda destino 93: 0 viajes
# Celda destino 94: 8 viajes
# Celda destino 95: 0 viajes
# Celda destino 96: 1 viajes
# Celda destino 97: 8 viajes
# Celda destino 98: 2 viajes
# Celda destino 99: 0 viajes
# Celda destino 100: 1 viajes
# Celda destino 101: 0 viajes
# Celda destino 102: 0 viajes
# Celda destino 103: 1 viajes
# Celda destino 104: 1 viajes
# Celda destino 105: 0 viajes
# Celda destino 106: 1 viajes
# Celda destino 107: 0 viajes
# Celda destino 108: 6 viajes
# Celda destino 109: 0 viajes
# Celda destino 110: 0 viajes
# Celda destino 111: 0 viajes
# Celda destino 112: 1 viajes
# Celda destino 113: 10 viajes
# Celda destino 114: 0 viajes
# Celda destino 115: 1 viajes
# Celda destino 116: 0 viajes
# Celda destino 117: 2 viajes
# Celda destino 118: 2 viajes
# Celda destino 119: 0 viajes
# Celda destino 120: 0 viajes
# Celda destino 121: 1 viajes
# Celda destino 122: 1 viajes
# Celda destino 123: 0 viajes
# Celda destino 124: 1 viajes
# Celda destino 125: 0 viajes
# Celda destino 126: 0 viajes
# Celda destino 127: 0 viajes
# Celda destino 128: 0 viajes
# Celda destino 129: 0 viajes
# Celda destino 130: 0 viajes
# Celda destino 131: 0 viajes
# Celda destino 132: 0 viajes
# Celda destino 133: 1 viajes
# Celda destino 134: 0 viajes
# Celda destino 135: 0 viajes
# Celda destino 136: 0 viajes
# Celda destino 137: 0 viajes
# Celda destino 138: 0 viajes
# Celda destino 139: 0 viajes
# Celda destino 140: 0 viajes
# Celda destino 141: 0 viajes
# Celda destino 142: 0 viajes
# Celda destino 143: 0 viajes
# Celda destino 144: 0 viajes
# TOTAL de viajes considerados: 484
# === VIAJES POR CELDA DESTINO ===
# Celda destino 0: 2 viajes
# Celda destino 1: 1 viajes
# Celda destino 2: 3 viajes
# Celda destino 3: 8 viajes
# Celda destino 4: 7 viajes
# Celda destino 5: 17 viajes
# Celda destino 6: 90 viajes
# Celda destino 7: 9 viajes
# Celda destino 8: 3 viajes
# Celda destino 9: 3 viajes
# Celda destino 10: 8 viajes
# Celda destino 11: 1 viajes
# Celda destino 12: 1 viajes
# Celda destino 13: 25 viajes
# Celda destino 14: 0 viajes
# Celda destino 15: 1 viajes
# Celda destino 16: 2 viajes
# Celda destino 17: 2 viajes
# Celda destino 18: 2 viajes
# Celda destino 19: 0 viajes
# Celda destino 20: 1 viajes
# Celda destino 21: 2 viajes
# Celda destino 22: 1 viajes
# Celda destino 23: 3 viajes
# Celda destino 24: 28 viajes
# Celda destino 25: 2 viajes
# Celda destino 26: 4 viajes
# Celda destino 27: 8 viajes
# Celda destino 28: 14 viajes
# Celda destino 29: 2 viajes
# Celda destino 30: 5 viajes
# Celda destino 31: 0 viajes
# Celda destino 32: 2 viajes
# Celda destino 33: 14 viajes
# Celda destino 34: 1 viajes
# Celda destino 35: 1 viajes
# Celda destino 36: 2 viajes
# Celda destino 37: 2 viajes
# Celda destino 38: 2 viajes
# Celda destino 39: 0 viajes
# Celda destino 40: 0 viajes
# Celda destino 41: 1 viajes
# Celda destino 42: 5 viajes
# Celda destino 43: 7 viajes
# Celda destino 44: 2 viajes
# Celda destino 45: 1 viajes
# Celda destino 46: 3 viajes
# Celda destino 47: 2 viajes
# Celda destino 48: 1 viajes
# Celda destino 49: 56 viajes
# Celda destino 50: 5 viajes
# Celda destino 51: 1 viajes
# Celda destino 52: 1 viajes
# Celda destino 53: 0 viajes
# Celda destino 54: 0 viajes
# Celda destino 55: 1 viajes
# Celda destino 56: 2 viajes
# Celda destino 57: 2 viajes
# Celda destino 58: 5 viajes
# Celda destino 59: 3 viajes
# Celda destino 60: 1 viajes
# Celda destino 61: 0 viajes
# Celda destino 62: 1 viajes
# Celda destino 63: 1 viajes
# Celda destino 64: 0 viajes
# Celda destino 65: 2 viajes
# Celda destino 66: 0 viajes
# Celda destino 67: 0 viajes
# Celda destino 68: 2 viajes
# Celda destino 69: 3 viajes
# Celda destino 70: 41 viajes
# Celda destino 71: 3 viajes
# Celda destino 72: 1 viajes
# Celda destino 73: 2 viajes
# Celda destino 74: 0 viajes
# Celda destino 75: 1 viajes
# Celda destino 76: 1 viajes
# Celda destino 77: 0 viajes
# Celda destino 78: 0 viajes
# Celda destino 79: 1 viajes
# Celda destino 80: 0 viajes
# Celda destino 81: 0 viajes
# Celda destino 82: 0 viajes
# Celda destino 83: 0 viajes
# Celda destino 84: 0 viajes
# Celda destino 85: 2 viajes
# Celda destino 86: 1 viajes
# Celda destino 87: 2 viajes
# Celda destino 88: 4 viajes
# Celda destino 89: 0 viajes
# Celda destino 90: 0 viajes
# Celda destino 91: 0 viajes
# Celda destino 92: 0 viajes
# Celda destino 93: 0 viajes
# Celda destino 94: 0 viajes
# Celda destino 95: 0 viajes
# Celda destino 96: 0 viajes
# Celda destino 97: 7 viajes
# Celda destino 98: 3 viajes
# Celda destino 99: 1 viajes
# Celda destino 100: 0 viajes
# Celda destino 101: 0 viajes
# Celda destino 102: 0 viajes
# Celda destino 103: 1 viajes
# Celda destino 104: 1 viajes
# Celda destino 105: 0 viajes
# Celda destino 106: 0 viajes
# Celda destino 107: 0 viajes
# Celda destino 108: 6 viajes
# Celda destino 109: 0 viajes
# Celda destino 110: 0 viajes
# Celda destino 111: 0 viajes
# Celda destino 112: 2 viajes
# Celda destino 113: 8 viajes
# Celda destino 114: 0 viajes
# Celda destino 115: 1 viajes
# Celda destino 116: 1 viajes
# Celda destino 117: 4 viajes
# Celda destino 118: 1 viajes
# Celda destino 119: 0 viajes
# Celda destino 120: 0 viajes
# Celda destino 121: 2 viajes
# Celda destino 122: 0 viajes
# Celda destino 123: 0 viajes
# Celda destino 124: 0 viajes
# Celda destino 125: 0 viajes
# Celda destino 126: 0 viajes
# Celda destino 127: 0 viajes
# Celda destino 128: 0 viajes
# Celda destino 129: 0 viajes
# Celda destino 130: 0 viajes
# Celda destino 131: 0 viajes
# Celda destino 132: 0 viajes
# Celda destino 133: 0 viajes
# Celda destino 134: 0 viajes
# Celda destino 135: 0 viajes
# Celda destino 136: 0 viajes
# Celda destino 137: 0 viajes
# Celda destino 138: 0 viajes
# Celda destino 139: 0 viajes
# Celda destino 140: 0 viajes
# Celda destino 141: 0 viajes
# Celda destino 142: 0 viajes
# Celda destino 143: 0 viajes
# Celda destino 144: 0 viajes
#
# TOTAL de viajes considerados: 484

# %% [markdown]
# # Celdas Origen Mapa de Calor

# %%
import folium
from folium import plugins
from branca.colormap import LinearColormap
import numpy as np
import matplotlib.pyplot as plt

def celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = (paso_m / (111000 * np.cos(np.radians(lat_min))))
 lat_centro = lat_min + (i + 0.5) * paso_lat
 lon_centro = lon_min + (j + 0.5) * paso_lon
 return lat_centro, lon_centro

# Cantidad de viajes por celda origen (sumando filas)
viajes_por_celda_origen = np.array([OD_original[i,:].sum() for i in range(len(celdas_unificadas))])

# Imprimir en terminal
print("=== VIAJES POR CELDA ORIGEN ===")
for idx, num_viajes in enumerate(viajes_por_celda_origen):
 print(f"Celda origen {idx}: {num_viajes} viajes")
print("\nTOTAL de viajes desde todas las celdas origen:", viajes_por_celda_origen.sum())

# Crear mapa centrado en el área
lat_centro = np.mean([lat_min, np.max(np.concatenate([tray[:,0] for tray in trayectorias]))])
lon_centro = np.mean([lon_min, np.max(np.concatenate([tray[:,1] for tray in trayectorias]))])
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=12, tiles="CartoDB positron")

# Crear colormap usando matplotlib 'plasma'
colormap = LinearColormap(
 colors=[plt.cm.plasma(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_origen.max()
)
colormap.caption = "Número de viajes desde celda origen"
colormap.add_to(m)

# Dibujar celdas origen
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))
 
 intensidad = viajes_por_celda_origen[idx]
 color_hex = colormap(intensidad)
 
 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color=color_hex,
 fill=True,
 fill_color=color_hex,
 fill_opacity=0.9,
 tooltip=f"Celda origen: {idx}\nViajes enviados: {intensidad}"
 ).add_to(m)

# Guardar mapa
m.save("../artifacts/laplace/maps/celdas_origen_original.html")
# Out:
# === VIAJES POR CELDA ORIGEN ===
# Celda origen 0: 3 viajes
# Celda origen 1: 1 viajes
# Celda origen 2: 2 viajes
# Celda origen 3: 8 viajes
# Celda origen 4: 68 viajes
# Celda origen 5: 31 viajes
# Celda origen 6: 14 viajes
# Celda origen 7: 6 viajes
# Celda origen 8: 2 viajes
# Celda origen 9: 2 viajes
# Celda origen 10: 7 viajes
# Celda origen 11: 1 viajes
# Celda origen 12: 5 viajes
# Celda origen 13: 21 viajes
# Celda origen 14: 0 viajes
# Celda origen 15: 2 viajes
# Celda origen 16: 3 viajes
# Celda origen 17: 1 viajes
# Celda origen 18: 3 viajes
# Celda origen 19: 1 viajes
# Celda origen 20: 0 viajes
# Celda origen 21: 1 viajes
# Celda origen 22: 0 viajes
# Celda origen 23: 3 viajes
# Celda origen 24: 16 viajes
# Celda origen 25: 2 viajes
# Celda origen 26: 3 viajes
# Celda origen 27: 7 viajes
# Celda origen 28: 12 viajes
# Celda origen 29: 2 viajes
# Celda origen 30: 4 viajes
# Celda origen 31: 3 viajes
# Celda origen 32: 10 viajes
# Celda origen 33: 38 viajes
# Celda origen 34: 1 viajes
# Celda origen 35: 1 viajes
# Celda origen 36: 1 viajes
# Celda origen 37: 2 viajes
# Celda origen 38: 1 viajes
# Celda origen 39: 1 viajes
# Celda origen 40: 0 viajes
# Celda origen 41: 0 viajes
# Celda origen 42: 8 viajes
# Celda origen 43: 2 viajes
# Celda origen 44: 4 viajes
# Celda origen 45: 3 viajes
# Celda origen 46: 1 viajes
# Celda origen 47: 4 viajes
# Celda origen 48: 13 viajes
# Celda origen 49: 20 viajes
# Celda origen 50: 2 viajes
# Celda origen 51: 0 viajes
# Celda origen 52: 1 viajes
# Celda origen 53: 5 viajes
# Celda origen 54: 1 viajes
# Celda origen 55: 1 viajes
# Celda origen 56: 5 viajes
# Celda origen 57: 1 viajes
# Celda origen 58: 4 viajes
# Celda origen 59: 5 viajes
# Celda origen 60: 0 viajes
# Celda origen 61: 1 viajes
# Celda origen 62: 1 viajes
# Celda origen 63: 1 viajes
# Celda origen 64: 1 viajes
# Celda origen 65: 23 viajes
# Celda origen 66: 0 viajes
# Celda origen 67: 0 viajes
# Celda origen 68: 0 viajes
# Celda origen 69: 4 viajes
# Celda origen 70: 21 viajes
# Celda origen 71: 2 viajes
# Celda origen 72: 7 viajes
# Celda origen 73: 1 viajes
# Celda origen 74: 1 viajes
# Celda origen 75: 2 viajes
# Celda origen 76: 3 viajes
# Celda origen 77: 0 viajes
# Celda origen 78: 0 viajes
# Celda origen 79: 1 viajes
# Celda origen 80: 0 viajes
# Celda origen 81: 0 viajes
# Celda origen 82: 0 viajes
# Celda origen 83: 2 viajes
# Celda origen 84: 0 viajes
# Celda origen 85: 2 viajes
# Celda origen 86: 1 viajes
# Celda origen 87: 0 viajes
# Celda origen 88: 1 viajes
# Celda origen 89: 0 viajes
# Celda origen 90: 2 viajes
# Celda origen 91: 0 viajes
# Celda origen 92: 2 viajes
# Celda origen 93: 0 viajes
# Celda origen 94: 0 viajes
# Celda origen 95: 0 viajes
# Celda origen 96: 2 viajes
# Celda origen 97: 4 viajes
# Celda origen 98: 3 viajes
# Celda origen 99: 1 viajes
# Celda origen 100: 0 viajes
# Celda origen 101: 0 viajes
# Celda origen 102: 0 viajes
# Celda origen 103: 3 viajes
# Celda origen 104: 1 viajes
# Celda origen 105: 0 viajes
# Celda origen 106: 0 viajes
# Celda origen 107: 0 viajes
# Celda origen 108: 6 viajes
# Celda origen 109: 0 viajes
# Celda origen 110: 0 viajes
# Celda origen 111: 0 viajes
# Celda origen 112: 0 viajes
# Celda origen 113: 5 viajes
# Celda origen 114: 0 viajes
# Celda origen 115: 0 viajes
# Celda origen 116: 0 viajes
# Celda origen 117: 3 viajes
# Celda origen 118: 3 viajes
# Celda origen 119: 0 viajes
# Celda origen 120: 2 viajes
# Celda origen 121: 2 viajes
# Celda origen 122: 1 viajes
# Celda origen 123: 0 viajes
# Celda origen 124: 0 viajes
# Celda origen 125: 0 viajes
# Celda origen 126: 0 viajes
# Celda origen 127: 0 viajes
# Celda origen 128: 0 viajes
# Celda origen 129: 0 viajes
# Celda origen 130: 0 viajes
# Celda origen 131: 0 viajes
# Celda origen 132: 0 viajes
# Celda origen 133: 0 viajes
# Celda origen 134: 0 viajes
# Celda origen 135: 0 viajes
# Celda origen 136: 0 viajes
# Celda origen 137: 0 viajes
# Celda origen 138: 0 viajes
# Celda origen 139: 0 viajes
# Celda origen 140: 0 viajes
# Celda origen 141: 0 viajes
# Celda origen 142: 0 viajes
# Celda origen 143: 0 viajes
# Celda origen 144: 0 viajes
#
# TOTAL de viajes desde todas las celdas origen: 484

# %%
import folium
from folium import plugins
from branca.colormap import LinearColormap
import numpy as np
import matplotlib.pyplot as plt

def celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = (paso_m / (111000 * np.cos(np.radians(lat_min))))
 lat_centro = lat_min + (i + 0.5) * paso_lat
 lon_centro = lon_min + (j + 0.5) * paso_lon
 return lat_centro, lon_centro

# Cantidad de viajes por celda origen (sumando filas)
viajes_por_celda_origen = np.array([OD_perturbada[i,:].sum() for i in range(len(celdas_unificadas))])

# Imprimir número de viajes por celda origen y total
print("=== VIAJES POR CELDA ORIGEN (PERTURBADA) ===")
for idx, num_viajes in enumerate(viajes_por_celda_origen):
 print(f"Celda origen {idx}: {num_viajes} viajes")
print("TOTAL de viajes desde todas las celdas origen:", viajes_por_celda_origen.sum())

# Crear mapa centrado
lat_centro = np.mean([lat_min, np.max(np.concatenate([tray[:,0] for tray in trayectorias]))])
lon_centro = np.mean([lon_min, np.max(np.concatenate([tray[:,1] for tray in trayectorias]))])
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=12, tiles="CartoDB positron")

# Crear colormap usando matplotlib 'plasma'
colormap = LinearColormap(
 colors=[plt.cm.plasma(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_origen.max()
)
colormap.caption = "Número de viajes desde celda origen (perturbada)"
colormap.add_to(m)

# Dibujar celdas origen
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))
 
 intensidad = viajes_por_celda_origen[idx]
 color_hex = colormap(intensidad)
 
 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color=color_hex,
 fill=True,
 fill_color=color_hex,
 fill_opacity=0.9,
 tooltip=f"Celda origen: {idx}\nViajes enviados: {intensidad}"
 ).add_to(m)

# Guardar mapa
m.save("../artifacts/laplace/maps/celdas_origen_perturbado.html")
# Out:
# === VIAJES POR CELDA ORIGEN (PERTURBADA) ===
# Celda origen 0: 2 viajes
# Celda origen 1: 0 viajes
# Celda origen 2: 3 viajes
# Celda origen 3: 5 viajes
# Celda origen 4: 66 viajes
# Celda origen 5: 31 viajes
# Celda origen 6: 12 viajes
# Celda origen 7: 4 viajes
# Celda origen 8: 3 viajes
# Celda origen 9: 5 viajes
# Celda origen 10: 5 viajes
# Celda origen 11: 1 viajes
# Celda origen 12: 7 viajes
# Celda origen 13: 22 viajes
# Celda origen 14: 0 viajes
# Celda origen 15: 3 viajes
# Celda origen 16: 3 viajes
# Celda origen 17: 1 viajes
# Celda origen 18: 2 viajes
# Celda origen 19: 1 viajes
# Celda origen 20: 0 viajes
# Celda origen 21: 1 viajes
# Celda origen 22: 0 viajes
# Celda origen 23: 6 viajes
# Celda origen 24: 17 viajes
# Celda origen 25: 4 viajes
# Celda origen 26: 4 viajes
# Celda origen 27: 9 viajes
# Celda origen 28: 11 viajes
# Celda origen 29: 4 viajes
# Celda origen 30: 4 viajes
# Celda origen 31: 3 viajes
# Celda origen 32: 9 viajes
# Celda origen 33: 35 viajes
# Celda origen 34: 2 viajes
# Celda origen 35: 1 viajes
# Celda origen 36: 2 viajes
# Celda origen 37: 2 viajes
# Celda origen 38: 1 viajes
# Celda origen 39: 1 viajes
# Celda origen 40: 0 viajes
# Celda origen 41: 0 viajes
# Celda origen 42: 5 viajes
# Celda origen 43: 2 viajes
# Celda origen 44: 4 viajes
# Celda origen 45: 3 viajes
# Celda origen 46: 2 viajes
# Celda origen 47: 4 viajes
# Celda origen 48: 8 viajes
# Celda origen 49: 20 viajes
# Celda origen 50: 1 viajes
# Celda origen 51: 0 viajes
# Celda origen 52: 1 viajes
# Celda origen 53: 4 viajes
# Celda origen 54: 0 viajes
# Celda origen 55: 1 viajes
# Celda origen 56: 4 viajes
# Celda origen 57: 1 viajes
# Celda origen 58: 4 viajes
# Celda origen 59: 9 viajes
# Celda origen 60: 0 viajes
# Celda origen 61: 1 viajes
# Celda origen 62: 0 viajes
# Celda origen 63: 0 viajes
# Celda origen 64: 2 viajes
# Celda origen 65: 19 viajes
# Celda origen 66: 1 viajes
# Celda origen 67: 2 viajes
# Celda origen 68: 1 viajes
# Celda origen 69: 3 viajes
# Celda origen 70: 18 viajes
# Celda origen 71: 2 viajes
# Celda origen 72: 7 viajes
# Celda origen 73: 0 viajes
# Celda origen 74: 1 viajes
# Celda origen 75: 1 viajes
# Celda origen 76: 2 viajes
# Celda origen 77: 5 viajes
# Celda origen 78: 0 viajes
# Celda origen 79: 1 viajes
# Celda origen 80: 1 viajes
# Celda origen 81: 0 viajes
# Celda origen 82: 0 viajes
# Celda origen 83: 1 viajes
# Celda origen 84: 0 viajes
# Celda origen 85: 3 viajes
# Celda origen 86: 0 viajes
# Celda origen 87: 0 viajes
# Celda origen 88: 2 viajes
# Celda origen 89: 0 viajes
# Celda origen 90: 2 viajes
# Celda origen 91: 0 viajes
# Celda origen 92: 2 viajes
# Celda origen 93: 0 viajes
# Celda origen 94: 3 viajes
# Celda origen 95: 0 viajes
# Celda origen 96: 2 viajes
# Celda origen 97: 5 viajes
# Celda origen 98: 1 viajes
# Celda origen 99: 1 viajes
# Celda origen 100: 0 viajes
# Celda origen 101: 0 viajes
# Celda origen 102: 0 viajes
# Celda origen 103: 2 viajes
# Celda origen 104: 1 viajes
# Celda origen 105: 0 viajes
# Celda origen 106: 0 viajes
# Celda origen 107: 0 viajes
# Celda origen 108: 5 viajes
# Celda origen 109: 1 viajes
# Celda origen 110: 0 viajes
# Celda origen 111: 0 viajes
# Celda origen 112: 0 viajes
# Celda origen 113: 4 viajes
# Celda origen 114: 0 viajes
# Celda origen 115: 0 viajes
# Celda origen 116: 2 viajes
# Celda origen 117: 3 viajes
# Celda origen 118: 2 viajes
# Celda origen 119: 0 viajes
# Celda origen 120: 3 viajes
# Celda origen 121: 2 viajes
# Celda origen 122: 1 viajes
# Celda origen 123: 0 viajes
# Celda origen 124: 1 viajes
# Celda origen 125: 0 viajes
# Celda origen 126: 0 viajes
# Celda origen 127: 0 viajes
# Celda origen 128: 1 viajes
# Celda origen 129: 0 viajes
# Celda origen 130: 0 viajes
# Celda origen 131: 0 viajes
# Celda origen 132: 0 viajes
# Celda origen 133: 1 viajes
# Celda origen 134: 0 viajes
# Celda origen 135: 1 viajes
# Celda origen 136: 0 viajes
# Celda origen 137: 0 viajes
# Celda origen 138: 0 viajes
# Celda origen 139: 0 viajes
# Celda origen 140: 0 viajes
# Celda origen 141: 0 viajes
# Celda origen 142: 0 viajes
# Celda origen 143: 0 viajes
# Celda origen 144: 0 viajes
# TOTAL de viajes desde todas las celdas origen: 484

# %% [markdown]
# # Mapa con trayectorias

# %%
import folium
from folium import plugins
from branca.colormap import LinearColormap
import numpy as np
import matplotlib.pyplot as plt

def celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = (paso_m / (111000 * np.cos(np.radians(lat_min))))
 lat_centro = lat_min + (i + 0.5) * paso_lat
 lon_centro = lon_min + (j + 0.5) * paso_lon
 return lat_centro, lon_centro

# Convertir sparse matrix a numpy array
OD_array = OD_original

# Viajes por celda origen y destino
viajes_por_celda_origen = np.array([OD_array[i,:].sum() for i in range(len(celdas_unificadas))])
viajes_por_celda_destino = np.array([OD_array[:, j].sum() for j in range(len(celdas_unificadas))])

# Crear mapa centrado
lat_centro = np.mean([lat_min, np.max(np.concatenate([tray[:,0] for tray in trayectorias]))])
lon_centro = np.mean([lon_min, np.max(np.concatenate([tray[:,1] for tray in trayectorias]))])
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=12, tiles="CartoDB positron")

# Colormaps
colormap_origen = LinearColormap(
 colors=[plt.cm.Blues(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_origen.max()
)
colormap_origen.caption = "Viajes desde celda origen"
colormap_origen.add_to(m)

colormap_destino = LinearColormap(
 colors=[plt.cm.Reds(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_destino.max()
)
colormap_destino.caption = "Viajes hacia celda destino"
colormap_destino.add_to(m)

# Dibujar celdas origen
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))

 intensidad_origen = viajes_por_celda_origen[idx]
 color_origen = colormap_origen(intensidad_origen)

 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color=color_origen,
 fill=True,
 fill_color=color_origen,
 fill_opacity=0.6,
 tooltip=f"Celda origen: {idx}\nViajes enviados: {intensidad_origen}"
 ).add_to(m)

# Dibujar celdas destino
# Dibujar celdas con info de origen y destino
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))

 intensidad_origen = viajes_por_celda_origen[idx]
 intensidad_destino = viajes_por_celda_destino[idx]

 # Color combinado (puedes elegir la media de ambos colores)
 color_origen = colormap_origen(intensidad_origen)
 color_destino = colormap_destino(intensidad_destino)
 # Aquí hacemos un color "promedio" visual simple mezclando ambos (aprox)
 color_combinado = f'#{int((int(color_origen[1:3],16)+int(color_destino[1:3],16))/2):02x}' \
 f'{int((int(color_origen[3:5],16)+int(color_destino[3:5],16))/2):02x}' \
 f'{int((int(color_origen[5:7],16)+int(color_destino[5:7],16))/2):02x}'

 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color=color_combinado,
 fill=True,
 fill_color=color_combinado,
 fill_opacity=0.6,
 tooltip=(f"Celda: {idx}\n"
 f"Viajes enviados: {intensidad_origen}\n"
 f"Viajes recibidos: {intensidad_destino}")
 ).add_to(m)


# Dibujar líneas desde origen a destino
max_viajes = OD_array.max() # para normalizar el grosor
for i in range(len(celdas_unificadas)):
 for j in range(len(celdas_unificadas)):
 if OD_array[i, j] > 0:
 lat_i, lon_i = celda_a_latlon_centro(*list(celdas_unificadas.keys())[i], lat_min, lon_min, paso_m)
 lat_j, lon_j = celda_a_latlon_centro(*list(celdas_unificadas.keys())[j], lat_min, lon_min, paso_m)
 folium.PolyLine(
 locations=[[lat_i, lon_i], [lat_j, lon_j]],
 color='gray',
 weight=OD_array[i,j]/max_viajes*5, # grosor proporcional
 opacity = 0.7 + 0.3 * (OD_array[i,j] / max_viajes)

 ).add_to(m)

# Guardar mapa
m.save("../artifacts/laplace/maps/celdas_origen_destino_original.html")

print("Mapa generado: 'celdas_origen_destino.html' ")
# Out:
# Mapa generado: 'celdas_origen_destino.html'

# %%
import folium
from folium import plugins
from branca.colormap import LinearColormap
import numpy as np
import matplotlib.pyplot as plt

def celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = (paso_m / (111000 * np.cos(np.radians(lat_min))))
 lat_centro = lat_min + (i + 0.5) * paso_lat
 lon_centro = lon_min + (j + 0.5) * paso_lon
 return lat_centro, lon_centro

# Convertir sparse matrix a numpy array
OD_array = OD_perturbada

# Viajes por celda origen y destino
viajes_por_celda_origen = np.array([OD_array[i,:].sum() for i in range(len(celdas_unificadas))])
viajes_por_celda_destino = np.array([OD_array[:, j].sum() for j in range(len(celdas_unificadas))])

# Crear mapa centrado
lat_centro = np.mean([lat_min, np.max(np.concatenate([tray[:,0] for tray in trayectorias]))])
lon_centro = np.mean([lon_min, np.max(np.concatenate([tray[:,1] for tray in trayectorias]))])
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=12, tiles="CartoDB positron")

# Colormaps
colormap_origen = LinearColormap(
 colors=[plt.cm.Blues(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_origen.max()
)
colormap_origen.caption = "Viajes desde celda origen"
colormap_origen.add_to(m)

colormap_destino = LinearColormap(
 colors=[plt.cm.Reds(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_destino.max()
)
colormap_destino.caption = "Viajes hacia celda destino"
colormap_destino.add_to(m)

# Dibujar celdas origen
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))

 intensidad_origen = viajes_por_celda_origen[idx]
 color_origen = colormap_origen(intensidad_origen)

 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color=color_origen,
 fill=True,
 fill_color=color_origen,
 fill_opacity=0.6,
 tooltip=f"Celda origen: {idx}\nViajes enviados: {intensidad_origen}"
 ).add_to(m)

# Dibujar celdas destino
# Dibujar celdas con info de origen y destino
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))

 intensidad_origen = viajes_por_celda_origen[idx]
 intensidad_destino = viajes_por_celda_destino[idx]

 # Color combinado (puedes elegir la media de ambos colores)
 color_origen = colormap_origen(intensidad_origen)
 color_destino = colormap_destino(intensidad_destino)
 # Aquí hacemos un color "promedio" visual simple mezclando ambos (aprox)
 color_combinado = f'#{int((int(color_origen[1:3],16)+int(color_destino[1:3],16))/2):02x}' \
 f'{int((int(color_origen[3:5],16)+int(color_destino[3:5],16))/2):02x}' \
 f'{int((int(color_origen[5:7],16)+int(color_destino[5:7],16))/2):02x}'

 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color=color_combinado,
 fill=True,
 fill_color=color_combinado,
 fill_opacity=0.6,
 tooltip=(f"Celda: {idx}\n"
 f"Viajes enviados: {intensidad_origen}\n"
 f"Viajes recibidos: {intensidad_destino}")
 ).add_to(m)


# Dibujar líneas desde origen a destino
max_viajes = OD_array.max() # para normalizar el grosor
for i in range(len(celdas_unificadas)):
 for j in range(len(celdas_unificadas)):
 if OD_array[i, j] > 0:
 lat_i, lon_i = celda_a_latlon_centro(*list(celdas_unificadas.keys())[i], lat_min, lon_min, paso_m)
 lat_j, lon_j = celda_a_latlon_centro(*list(celdas_unificadas.keys())[j], lat_min, lon_min, paso_m)
 folium.PolyLine(
 locations=[[lat_i, lon_i], [lat_j, lon_j]],
 color='gray',
 weight=OD_array[i,j]/max_viajes*5, # grosor proporcional
 opacity = 0.7 + 0.3 * (OD_array[i,j] / max_viajes)

 ).add_to(m)

# Guardar mapa
m.save("../artifacts/laplace/maps/celdas_origen_destino_perturbada.html")

print("Mapa generado: 'celdas_origen_destino_perturbada.html' ")
# Out:
# Mapa generado: 'celdas_origen_destino_perturbada.html'

# %% [markdown]
# # Graficas con flechas

# %%
import folium
from folium import plugins
from branca.colormap import LinearColormap
import numpy as np
import matplotlib.pyplot as plt

# Función para obtener el centro de la celda
def celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = (paso_m / (111000 * np.cos(np.radians(lat_min))))
 lat_centro = lat_min + (i + 0.5) * paso_lat
 lon_centro = lon_min + (j + 0.5) * paso_lon
 return lat_centro, lon_centro

# Convertir sparse matrix a numpy array
OD_array = OD_original

# Viajes por celda origen y destino
viajes_por_celda_origen = np.array([OD_array[i,:].sum() for i in range(len(celdas_unificadas))])
viajes_por_celda_destino = np.array([OD_array[:, j].sum() for j in range(len(celdas_unificadas))])

# Crear mapa centrado
lat_centro = np.mean([lat_min, np.max(np.concatenate([tray[:,0] for tray in trayectorias]))])
lon_centro = np.mean([lon_min, np.max(np.concatenate([tray[:,1] for tray in trayectorias]))])
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=12, tiles="CartoDB positron")

# Colormaps
colormap_origen = LinearColormap(
 colors=[plt.cm.Blues(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_origen.max()
)
colormap_origen.caption = "Viajes desde celda origen"
colormap_origen.add_to(m)

colormap_destino = LinearColormap(
 colors=[plt.cm.Reds(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_destino.max()
)
colormap_destino.caption = "Viajes hacia celda destino"
colormap_destino.add_to(m)

# Dibujar celdas con info de origen y destino
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))

 intensidad_origen = viajes_por_celda_origen[idx]
 intensidad_destino = viajes_por_celda_destino[idx]

 # Color combinado (aproximación)
 color_origen = colormap_origen(intensidad_origen)
 color_destino = colormap_destino(intensidad_destino)
 color_combinado = f'#{int((int(color_origen[1:3],16)+int(color_destino[1:3],16))/2):02x}' \
 f'{int((int(color_origen[3:5],16)+int(color_destino[3:5],16))/2):02x}' \
 f'{int((int(color_origen[5:7],16)+int(color_destino[5:7],16))/2):02x}'

 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color=color_combinado,
 fill=True,
 fill_color=color_combinado,
 fill_opacity=0.6,
 tooltip=(f"Celda: {idx}\n"
 f"Viajes enviados: {intensidad_origen}\n"
 f"Viajes recibidos: {intensidad_destino}")
 ).add_to(m)

# Dibujar líneas con dirección
max_viajes = OD_array.max() # para normalizar grosor
for i in range(len(celdas_unificadas)):
 for j in range(len(celdas_unificadas)):
 if OD_array[i, j] > 0:
 lat_i, lon_i = celda_a_latlon_centro(*list(celdas_unificadas.keys())[i], lat_min, lon_min, paso_m)
 lat_j, lon_j = celda_a_latlon_centro(*list(celdas_unificadas.keys())[j], lat_min, lon_min, paso_m)
 
 # Línea proporcional a viajes
 linea = folium.PolyLine(
 locations=[[lat_i, lon_i], [lat_j, lon_j]],
 color='gray',
 weight=OD_array[i,j]/max_viajes*5,
 opacity = 0.7 + 0.3 * (OD_array[i,j] / max_viajes)
 ).add_to(m)
 
 # Flecha indicando dirección
 plugins.PolyLineTextPath(
 linea,
 '', # símbolo de flecha
 repeat=True,
 offset=6,
 attributes={'fill': 'black', 'font-weight': 'bold', 'font-size': '12'}
 ).add_to(m)

# Guardar mapa
m.save("../artifacts/laplace/maps/celdas_origen_destino_flujo.html")

print("Mapa generado: 'celdas_origen_destino_flujo.html' ")
# Out:
# Mapa generado: 'celdas_origen_destino_flujo.html'

# %%
import folium
from folium import plugins
from branca.colormap import LinearColormap
import numpy as np
import matplotlib.pyplot as plt

# Función para obtener el centro de la celda
def celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = (paso_m / (111000 * np.cos(np.radians(lat_min))))
 lat_centro = lat_min + (i + 0.5) * paso_lat
 lon_centro = lon_min + (j + 0.5) * paso_lon
 return lat_centro, lon_centro

# Convertir sparse matrix a numpy array
OD_array = OD_original

# Viajes por celda origen y destino
viajes_por_celda_origen = np.array([OD_array[i,:].sum() for i in range(len(celdas_unificadas))])
viajes_por_celda_destino = np.array([OD_array[:, j].sum() for j in range(len(celdas_unificadas))])

# Crear mapa centrado
lat_centro = np.mean([lat_min, np.max(np.concatenate([tray[:,0] for tray in trayectorias]))])
lon_centro = np.mean([lon_min, np.max(np.concatenate([tray[:,1] for tray in trayectorias]))])
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=12, tiles="CartoDB positron")

# Colormaps
colormap_origen = LinearColormap(
 colors=[plt.cm.Blues(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_origen.max()
)
colormap_origen.caption = "Viajes desde celda origen"
colormap_origen.add_to(m)

colormap_destino = LinearColormap(
 colors=[plt.cm.Reds(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_destino.max()
)
colormap_destino.caption = "Viajes hacia celda destino"
colormap_destino.add_to(m)

# Dibujar celdas con info de origen y destino
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))

 intensidad_origen = viajes_por_celda_origen[idx]
 intensidad_destino = viajes_por_celda_destino[idx]

 # Color combinado (aproximación)
 color_origen = colormap_origen(intensidad_origen)
 color_destino = colormap_destino(intensidad_destino)
 color_combinado = f'#{int((int(color_origen[1:3],16)+int(color_destino[1:3],16))/2):02x}' \
 f'{int((int(color_origen[3:5],16)+int(color_destino[3:5],16))/2):02x}' \
 f'{int((int(color_origen[5:7],16)+int(color_destino[5:7],16))/2):02x}'

 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color=color_combinado,
 fill=True,
 fill_color=color_combinado,
 fill_opacity=0.6,
 tooltip=(f"Celda: {idx}\n"
 f"Viajes enviados: {intensidad_origen}\n"
 f"Viajes recibidos: {intensidad_destino}")
 ).add_to(m)

# Dibujar líneas animadas (AntPath) con dirección
# Dibujar líneas animadas (AntPath) con dirección
max_viajes = OD_array.max() # para normalizar grosor
for i in range(len(celdas_unificadas)):
 for j in range(len(celdas_unificadas)):
 if OD_array[i, j] > 0:
 lat_i, lon_i = celda_a_latlon_centro(*list(celdas_unificadas.keys())[i], lat_min, lon_min, paso_m)
 lat_j, lon_j = celda_a_latlon_centro(*list(celdas_unificadas.keys())[j], lat_min, lon_min, paso_m)
 
 # Grosor proporcional con mínimo más grueso
 weight = 2 + (OD_array[i,j]/max_viajes*5) # mínimo 2, máximo 7 aprox.
 
 plugins.AntPath(
 locations=[[lat_i, lon_i], [lat_j, lon_j]],
 dash_array=[10, 20],
 delay=1000,
 color='blue',
 pulse_color='white',
 weight=weight
 ).add_to(m)


# Guardar mapa
m.save("../artifacts/laplace/maps/celdas_origen_destino_animado.html")

print("Mapa generado: 'celdas_origen_destino_animado.html' ")
# Out:
# Mapa generado: 'celdas_origen_destino_animado.html'

# %% [markdown]
# # Graficas animadas interactivas

# %%
import folium
from folium import plugins
from branca.colormap import LinearColormap, linear
import numpy as np
import matplotlib.pyplot as plt

# Función para obtener el centro de la celda
def celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = (paso_m / (111000 * np.cos(np.radians(lat_min))))
 lat_centro = lat_min + (i + 0.5) * paso_lat
 lon_centro = lon_min + (j + 0.5) * paso_lon
 return lat_centro, lon_centro

# Convertir sparse matrix a numpy array
OD_array = OD_original

# Viajes por celda origen y destino
viajes_por_celda_origen = np.array([OD_array[i,:].sum() for i in range(len(celdas_unificadas))])
viajes_por_celda_destino = np.array([OD_array[:, j].sum() for j in range(len(celdas_unificadas))])

# Crear mapa centrado
lat_centro = np.mean([lat_min, np.max(np.concatenate([tray[:,0] for tray in trayectorias]))])
lon_centro = np.mean([lon_min, np.max(np.concatenate([tray[:,1] for tray in trayectorias]))])
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=12, tiles="CartoDB positron")

# Colormaps para celdas
colormap_origen = LinearColormap(
 colors=[plt.cm.Blues(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_origen.max()
)
colormap_origen.caption = "Viajes desde celda origen"
colormap_origen.add_to(m)

colormap_destino = LinearColormap(
 colors=[plt.cm.Reds(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_destino.max()
)
colormap_destino.caption = "Viajes hacia celda destino"
colormap_destino.add_to(m)

# Dibujar celdas con info de origen y destino (totales)
# Dibujar celdas con info de origen y destino (totales + detalle de viajes recibidos)
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))

 intensidad_origen = viajes_por_celda_origen[idx]
 intensidad_destino = viajes_por_celda_destino[idx]

 # Color combinado aproximado
 color_origen = colormap_origen(intensidad_origen)
 color_destino = colormap_destino(intensidad_destino)
 color_combinado = f'#{int((int(color_origen[1:3],16)+int(color_destino[1:3],16))/2):02x}' \
 f'{int((int(color_origen[3:5],16)+int(color_destino[3:5],16))/2):02x}' \
 f'{int((int(color_origen[5:7],16)+int(color_destino[5:7],16))/2):02x}'

 # Detalle de los orígenes de los viajes recibidos
 detalle_origenes = ""
 for origen, cantidad in enumerate(OD_array[:, idx]):
 if cantidad > 0:
 if origen == idx:
 detalle_origenes += f" → Desde esta misma celda: {cantidad} viaje(s)<br>"
 else:
 detalle_origenes += f" → Desde celda {origen}: {cantidad} viaje(s)<br>"

 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color='black', 
 weight=1,
 fill=True,
 fill_color=color_combinado,
 fill_opacity=0.5, 
 tooltip=(f"<b>Celda {idx}</b><br>"
 f"Total viajes enviados desde esta celda: {intensidad_origen}<br>"
 f"Total viajes recibidos en esta celda: {intensidad_destino}<br>"
 f"<b>Detalle viajes recibidos:</b><br>"
 f"{detalle_origenes}")
 ).add_to(m)


# Dibujar líneas animadas (AntPath) mostrando solo viajes origen→destino
max_viajes = OD_array.max()
for i in range(len(celdas_unificadas)):
 for j in range(len(celdas_unificadas)):
 if OD_array[i, j] > 0:
 lat_i, lon_i = celda_a_latlon_centro(*list(celdas_unificadas.keys())[i], lat_min, lon_min, paso_m)
 lat_j, lon_j = celda_a_latlon_centro(*list(celdas_unificadas.keys())[j], lat_min, lon_min, paso_m)
 
 # Grosor proporcional con mínimo más grueso
 weight = 2 + (OD_array[i,j]/max_viajes*5)
 
 # Color degradado azul→rojo según intensidad de la línea
 color_line = f"rgba({int(255 * (1 - OD_array[i,j]/max_viajes))},0,{int(255 * (OD_array[i,j]/max_viajes))},1)"
 
 plugins.AntPath(
 locations=[[lat_i, lon_i], [lat_j, lon_j]],
 dash_array=[10, 20],
 delay=700, # animación rápida
 color=color_line, # degradado
 pulse_color='white',
 weight=weight,
 tooltip=(f"Viajes desde celda {i} a celda {j}: {OD_array[i,j]}")
 ).add_to(m)

# Guardar mapa
m.save("../artifacts/laplace/maps/celdas_origen_destino_tooltips_claros.html")
print("Mapa generado: 'celdas_origen_destino_tooltips_claros.html' ")
# Out:
# Mapa generado: 'celdas_origen_destino_tooltips_claros.html'

# %%
import folium
from folium import plugins
from branca.colormap import LinearColormap, linear
import numpy as np
import matplotlib.pyplot as plt

# Función para obtener el centro de la celda
def celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m):
 paso_lat = paso_m / 111000
 paso_lon = (paso_m / (111000 * np.cos(np.radians(lat_min))))
 lat_centro = lat_min + (i + 0.5) * paso_lat
 lon_centro = lon_min + (j + 0.5) * paso_lon
 return lat_centro, lon_centro

# Convertir sparse matrix a numpy array
OD_array = OD_perturbada

# Viajes por celda origen y destino
viajes_por_celda_origen = np.array([OD_array[i,:].sum() for i in range(len(celdas_unificadas))])
viajes_por_celda_destino = np.array([OD_array[:, j].sum() for j in range(len(celdas_unificadas))])

# Crear mapa centrado
lat_centro = np.mean([lat_min, np.max(np.concatenate([tray[:,0] for tray in trayectorias]))])
lon_centro = np.mean([lon_min, np.max(np.concatenate([tray[:,1] for tray in trayectorias]))])
m = folium.Map(location=[lat_centro, lon_centro], zoom_start=12, tiles="CartoDB positron")

# Colormaps para celdas
colormap_origen = LinearColormap(
 colors=[plt.cm.Blues(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_origen.max()
)
colormap_origen.caption = "Viajes desde celda origen"
colormap_origen.add_to(m)

colormap_destino = LinearColormap(
 colors=[plt.cm.Reds(i/255)[:3] for i in range(0,256,5)],
 vmin=0,
 vmax=viajes_por_celda_destino.max()
)
colormap_destino.caption = "Viajes hacia celda destino"
colormap_destino.add_to(m)

# Dibujar celdas con info de origen y destino (totales)
# Dibujar celdas con info de origen y destino (totales + detalle de viajes recibidos)
for (i, j), idx in celdas_unificadas.items():
 lat_c, lon_c = celda_a_latlon_centro(i, j, lat_min, lon_min, paso_m)
 radio_lat = (paso_m / 2) / 111000
 radio_lon = (paso_m / 2) / (111000 * np.cos(np.radians(lat_c)))

 intensidad_origen = viajes_por_celda_origen[idx]
 intensidad_destino = viajes_por_celda_destino[idx]

 # Color combinado aproximado
 color_origen = colormap_origen(intensidad_origen)
 color_destino = colormap_destino(intensidad_destino)
 color_combinado = f'#{int((int(color_origen[1:3],16)+int(color_destino[1:3],16))/2):02x}' \
 f'{int((int(color_origen[3:5],16)+int(color_destino[3:5],16))/2):02x}' \
 f'{int((int(color_origen[5:7],16)+int(color_destino[5:7],16))/2):02x}'

 # Detalle de los orígenes de los viajes recibidos
 detalle_origenes = ""
 for origen, cantidad in enumerate(OD_array[:, idx]):
 if cantidad > 0:
 if origen == idx:
 detalle_origenes += f" → Desde esta misma celda: {cantidad} viaje(s)<br>"
 else:
 detalle_origenes += f" → Desde celda {origen}: {cantidad} viaje(s)<br>"

 folium.Rectangle(
 bounds=[[lat_c - radio_lat, lon_c - radio_lon],
 [lat_c + radio_lat, lon_c + radio_lon]],
 color='black', 
 weight=1,
 fill=True,
 fill_color=color_combinado,
 fill_opacity=0.5, 
 tooltip=(f"<b>Celda {idx}</b><br>"
 f"Total viajes enviados desde esta celda: {intensidad_origen}<br>"
 f"Total viajes recibidos en esta celda: {intensidad_destino}<br>"
 f"<b>Detalle viajes recibidos:</b><br>"
 f"{detalle_origenes}")
 ).add_to(m)


# Dibujar líneas animadas (AntPath) mostrando solo viajes origen→destino
max_viajes = OD_array.max()
for i in range(len(celdas_unificadas)):
 for j in range(len(celdas_unificadas)):
 if OD_array[i, j] > 0:
 lat_i, lon_i = celda_a_latlon_centro(*list(celdas_unificadas.keys())[i], lat_min, lon_min, paso_m)
 lat_j, lon_j = celda_a_latlon_centro(*list(celdas_unificadas.keys())[j], lat_min, lon_min, paso_m)
 
 # Grosor proporcional con mínimo más grueso
 weight = 2 + (OD_array[i,j]/max_viajes*5)
 
 # Color degradado azul→rojo según intensidad de la línea
 color_line = f"rgba({int(255 * (1 - OD_array[i,j]/max_viajes))},0,{int(255 * (OD_array[i,j]/max_viajes))},1)"
 
 plugins.AntPath(
 locations=[[lat_i, lon_i], [lat_j, lon_j]],
 dash_array=[10, 20],
 delay=700, # animación rápida
 color=color_line, # degradado
 pulse_color='white',
 weight=weight,
 tooltip=(f"Viajes desde celda {i} a celda {j}: {OD_array[i,j]}")
 ).add_to(m)

# Guardar mapa
m.save("../artifacts/laplace/maps/celdas_origen_destino_tooltips_claros_perturbada.html")
print("Mapa generado: 'celdas_origen_destino_tooltips_perturbada.html' ")
# Out:
# Mapa generado: 'celdas_origen_destino_tooltips_perturbada.html'

# %% [markdown]
# # Comparacion de matrices

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os

# ================================
# CONFIGURACIÓN
# ================================
carpeta_salida = "../artifacts/laplace/analysis_outputs"

# Buscar todos los pares de archivos originales y perturbados
archivos_original = sorted(glob.glob(os.path.join(carpeta_salida, "OD_original_eps*.csv")))
archivos_perturbada = sorted(glob.glob(os.path.join(carpeta_salida, "OD_perturbada_eps*.csv")))

# Lista donde guardaremos los resultados de las métricas
resultados = []

# ================================
# 1⃣ CALCULAR MÉTRICAS PARA CADA PAR
# ================================
for orig_file, pert_file in zip(archivos_original, archivos_perturbada):
 # Extraer epsilon y paso_m desde el nombre del archivo
 nombre = os.path.basename(orig_file)
 partes = nombre.replace(".csv", "").split("_")
 epsilon = float(partes[2].replace("eps", ""))
 paso_m = int(partes[3].replace("paso", ""))

 # Cargar matrices originales y perturbadas
 original = pd.read_csv(orig_file, header=0).values
 perturbada = pd.read_csv(pert_file, header=0).values

 # Calcular MAE (Error Absoluto Medio)
 mae = np.mean(np.abs(original - perturbada))
 mae_norm = mae / np.max(original) if np.max(original) != 0 else 0

 # Calcular Error Relativo Celda a Celda (promedio)
 # Evitar divisiones por cero ignorando celdas donde original == 0
 mask = original != 0
 if np.any(mask):
 error_relativo = np.mean(np.abs((original[mask] - perturbada[mask]) / original[mask]))
 else:
 error_relativo = 0

 # Calcular Norma de Frobenius (diferencia matricial)
 frobenius = np.linalg.norm(original - perturbada)
 frobenius_norm = frobenius / np.linalg.norm(original) if np.linalg.norm(original) != 0 else 0

 # Guardar resultados
 resultados.append({
 "epsilon": epsilon,
 "paso_m": paso_m,
 "MAE": mae,
 "MAE_normalizado": mae_norm,
 "Error_relativo": error_relativo,
 "Frobenius_normalizada": frobenius_norm
 })

# Verificar si hay resultados
if not resultados:
 raise ValueError(" No se encontraron archivos OD_original_eps*.csv y OD_perturbada_eps*.csv en la carpeta especificada.")

# Convertir los resultados en un DataFrame ordenado
df_resultados = pd.DataFrame(resultados).sort_values(by=["paso_m", "epsilon"])

# Guardar los resultados en CSV
archivo_resultados = os.path.join(carpeta_salida, "metricas_comparacion.csv")
df_resultados.to_csv(archivo_resultados, index=False)
print(f" Métricas guardadas en: {archivo_resultados}")

# ================================
# 2⃣ MOSTRAR TABLA DE VALORES
# ================================
print("\n" + "="*80)
print("TABLA DE VALORES - MECANISMO DE LAPLACE PARA PERTURBACIÓN DE COORDENADAS")
print("="*80)
print(df_resultados.to_string(index=False))
print("="*80 + "\n")

# ================================
# 3⃣ GRAFICAR LAS MÉTRICAS (SOLO PUNTOS PARES)
# ================================
fig = plt.figure(figsize=(10, 13))
fig.suptitle("Mecanismo de Laplace para Perturbación de Coordenadas", fontsize=16, y=0.995)

# --- Gráfico 1: MAE (absoluto) ---
plt.subplot(4, 1, 1)
for paso in sorted(df_resultados["paso_m"].unique()):
 datos = df_resultados[df_resultados["paso_m"] == paso]
 # Filtrar solo índices pares (0, 2, 4, 6, ...)
 datos_pares = datos.iloc[::2]
 plt.plot(datos_pares["epsilon"], datos_pares["MAE"], marker='o', label=f"paso = {paso} m")
plt.title("MAE (Error Absoluto Medio) vs Epsilon", fontsize=11)
plt.xlabel("Epsilon (ε)")
plt.ylabel("MAE")
plt.legend()
plt.grid(True, alpha=0.3)

# --- Gráfico 2: MAE Normalizado ---
plt.subplot(4, 1, 2)
for paso in sorted(df_resultados["paso_m"].unique()):
 datos = df_resultados[df_resultados["paso_m"] == paso]
 # Filtrar solo índices pares
 datos_pares = datos.iloc[::2]
 plt.plot(datos_pares["epsilon"], datos_pares["MAE_normalizado"], marker='o', label=f"paso = {paso} m")
plt.title("MAE Normalizado vs Epsilon", fontsize=11)
plt.xlabel("Epsilon (ε)")
plt.ylabel("MAE normalizado")
plt.legend()
plt.grid(True, alpha=0.3)

# --- Gráfico 3: Error Relativo Promedio ---
plt.subplot(4, 1, 3)
for paso in sorted(df_resultados["paso_m"].unique()):
 datos = df_resultados[df_resultados["paso_m"] == paso]
 # Filtrar solo índices pares
 datos_pares = datos.iloc[::2]
 plt.plot(datos_pares["epsilon"], datos_pares["Error_relativo"], marker='o', label=f"paso = {paso} m")
plt.title("Error Relativo Promedio vs Epsilon", fontsize=11)
plt.xlabel("Epsilon (ε)")
plt.ylabel("Error relativo promedio")
plt.legend()
plt.grid(True, alpha=0.3)

# --- Gráfico 4: Norma de Frobenius ---
plt.subplot(4, 1, 4)
for paso in sorted(df_resultados["paso_m"].unique()):
 datos = df_resultados[df_resultados["paso_m"] == paso]
 # Filtrar solo índices pares
 datos_pares = datos.iloc[::2]
 plt.plot(datos_pares["epsilon"], datos_pares["Frobenius_normalizada"], marker='o', label=f"paso = {paso} m")
plt.title("Norma Frobenius Normalizada vs Epsilon", fontsize=11)
plt.xlabel("Epsilon (ε)")
plt.ylabel("Error Frobenius normalizado")
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(carpeta_salida, "graficas_metricas.png"), dpi=300, bbox_inches='tight')
print(f" Gráficas guardadas en: {os.path.join(carpeta_salida, 'graficas_metricas.png')}")
plt.show()

# ================================
# 4⃣ CREAR TABLA FORMATEADA EN HTML (OPCIONAL)
# ================================
tabla_html = df_resultados.to_html(index=False, float_format=lambda x: f'{x:.6f}')
archivo_tabla = os.path.join(carpeta_salida, "tabla_metricas.html")
with open(archivo_tabla, 'w') as f:
 f.write(f"<h2>Mecanismo de Laplace para Perturbación de Coordenadas - Tabla de Métricas</h2>\n{tabla_html}")
print(f" Tabla HTML guardada en: {archivo_tabla}")
# Out:
#  Métricas guardadas en: ../artifacts/laplace/analysis_outputs\metricas_comparacion.csv
#
# ================================================================================
# TABLA DE VALORES - MECANISMO DE LAPLACE PARA PERTURBACIÓN DE COORDENADAS
# ================================================================================
#  epsilon paso_m MAE MAE_normalizado Error_relativo Frobenius_normalizada
#  0.00822 1000 0.013985 0.000254 0.446582 0.342822
#  0.01264 1000 0.011786 0.000193 0.403623 0.253343
#  0.01706 1000 0.007123 0.000162 0.258148 0.161515
#  0.02148 1000 0.006958 0.000105 0.255512 0.190563
#  0.02590 1000 0.005463 0.000084 0.175227 0.118987
#  0.03032 1000 0.006551 0.000164 0.173763 0.264151
#  0.03474 1000 0.004683 0.000106 0.131807 0.166184
#  0.03916 1000 0.003456 0.000072 0.117703 0.101751
#  0.04358 1000 0.003569 0.000057 0.114293 0.092080
#  0.04800 1000 0.004031 0.000066 0.128884 0.118514
#  0.00822 1500 0.036405 0.000492 0.330427 0.270979
#  0.01264 1500 0.023438 0.000361 0.227373 0.127271
#  0.01706 1500 0.030637 0.000578 0.257236 0.153660
#  0.02148 1500 0.031738 0.000690 0.222200 0.262386
#  0.02590 1500 0.022575 0.000579 0.135293 0.204526
#  0.03032 1500 0.026667 0.000684 0.171186 0.198347
#  0.03474 1500 0.023650 0.000473 0.183729 0.189626
#  0.03916 1500 0.018812 0.000482 0.113184 0.185359
#  0.04358 1500 0.015609 0.000274 0.110546 0.111353
#  0.04800 1500 0.017200 0.000307 0.129063 0.141692
#  0.00822 2000 0.064050 0.001104 0.365646 0.153913
#  0.01264 2000 0.050000 0.001064 0.183791 0.105605
#  0.01706 2000 0.038133 0.000443 0.189127 0.081020
#  0.02148 2000 0.037984 0.000442 0.172879 0.075667
#  0.02590 2000 0.040906 0.000744 0.115859 0.170441
#  0.03032 2000 0.044753 0.000581 0.131837 0.139223
#  0.03474 2000 0.035494 0.000438 0.118826 0.120376
#  0.03916 2000 0.041667 0.000347 0.136351 0.108111
#  0.04358 2000 0.037551 0.000313 0.108557 0.084618
#  0.04800 2000 0.031020 0.000244 0.106768 0.066848
#  0.00822 2500 0.114796 0.001617 0.287598 0.139683
#  0.01264 2500 0.215976 0.002880 0.335940 0.264719
#  0.01706 2500 0.108800 0.001470 0.197662 0.121025
#  0.02148 2500 0.041588 0.000526 0.039736 0.043674
#  0.02590 2500 0.037807 0.000473 0.093419 0.035726
#  0.03032 2500 0.028926 0.000366 0.038172 0.030003
#  0.03474 2500 0.033058 0.000403 0.073763 0.033862
#  0.03916 2500 0.033058 0.000403 0.059783 0.033860
#  0.04358 2500 0.024793 0.000302 0.052151 0.031911
#  0.04800 2500 0.016529 0.000199 0.036595 0.022542
#  0.00822 3000 0.181406 0.001564 0.371756 0.100340
#  0.01264 3000 0.120000 0.001319 0.153686 0.078185
#  0.01706 3000 0.148148 0.001628 0.223447 0.065931
#  0.02148 3000 0.141975 0.001595 0.197420 0.088633
#  0.02590 3000 0.160494 0.002260 0.099198 0.139305
#  0.03032 3000 0.148148 0.002554 0.175490 0.122565
#  0.03474 3000 0.179012 0.002841 0.205505 0.205111
#  0.03916 3000 0.135802 0.000977 0.116128 0.133516
#  0.04358 3000 0.111111 0.001111 0.163128 0.085566
#  0.04800 3000 0.080247 0.000613 0.080463 0.051147
# ================================================================================
#
#  Gráficas guardadas en: ../artifacts/laplace/analysis_outputs\graficas_metricas.png
#  Tabla HTML guardada en: ../artifacts/laplace/analysis_outputs\tabla_metricas.html
